# %% [markdown]
# # **Compute Sentiment Using 4 SyuzhetR and 7 SentimentR Models**
#
# * https://www.youtube.com/watch?v=U3ByGh8RmSc
#
# * https://github.com/ttimbers/intro-to-reticulate
#
# [Use R on Google Colab!](https://colab.research.google.com/notebook#create=true&language=r)

# %% [markdown]
# # **[STEP 1] Manual Configuration/Setup**

# %% [markdown]
# ## (Popups) Connect Google gDrive

# %%
# [INPUT REQUIRED]: Authorize access to Google gDrive

# Connect this Notebook to your permanent Google Drive
#   so all generated output is saved to permanent storage there

try:
  from google.colab import drive
  IN_COLAB=True
except:
  IN_COLAB=False

if IN_COLAB:
  print("Attempting to attach your Google gDrive to this Colab Jupyter Notebook")
  drive.mount('/gdrive', force_remount=True)
else:
  print("Your Google gDrive is attached to this Colab Jupyter Notebook")
# Out:
# Attempting to attach your Google gDrive to this Colab Jupyter Notebook
# Mounted at /gdrive

# %% [markdown]
# ## (3 Inputs) Define Directory Tree

# %%
# [CUSTOMIZE]: Change the text after the Unix '%cd ' command below (change directory)
#              to math the full path to your gDrive subdirectory which should be the 
#              root directory cloned from the SentimentArcs github repo.

# NOTE: Make sure this subdirectory already exists and there are 
#       no typos, spaces or illegals characters (e.g. periods) in the full path after %cd

# NOTE: In Python all strings must begin with an upper or lowercase letter, and only
#         letter, number and underscores ('_') characters should appear afterwards.
#         Make sure your full path after %cd obeys this constraint or errors may appear.

# #@markdown **Instructions**

# #@markdown Set Directory and Corpus names:
# #@markdown <li> Set <b>Path_to_SentimentArcs</b> to the project root in your **GDrive folder**
# #@markdown <li> Set <b>Corpus_Genre</b> = [novels, finance, social_media]
# #@markdown <li> <b>Corpus_Type</b> = [reference_corpus, new_corpus]
# #@markdown <li> <b>Corpus_Number</b> = [1-20] (id nunmber if a new_corpus)

#@markdown <hr>

# Step #1: Get full path to SentimentArcs subdir on gDrive
# =======
#@markdown **Accept default path on gDrive or Enter new one:**

Path_to_SentimentArcs = "/gdrive/MyDrive/sentimentarcs_notebooks/" #@param ["/gdrive/MyDrive/sentiment_arcs/"] {allow-input: true}


#@markdown Set this to the project root in your <b>GDrive folder</b>
#@markdown <br> (e.g. /<wbr><b>gdrive/MyDrive/research/sentiment_arcs/</b>)

#@markdown <hr>

#@markdown **Which type of texts are you cleaning?** \

Corpus_Genre = "novels" #@param ["novels", "social_media", "finance"]

# Corpus_Type = "reference" #@param ["new", "reference"]
Corpus_Type = "new" #@param ["new", "reference"]


Corpus_Number = 2 #@param {type:"slider", min:1, max:10, step:1}


#@markdown Put in the corresponding Subdirectory under **./text_raw**:
#@markdown <li> All Texts as clean <b>plaintext *.txt</b> files 
#@markdown <li> A <b>YAML Configuration File</b> describing each Texts

#@markdown Please verify the required textfiles and YAML file exist in the correct subdirectories before continuing.

print('Current Working Directory:')
# %cd $Path_to_SentimentArcs

print('\n')

if Corpus_Type == 'reference':
  SUBDIR_SENTIMENT_RAW = f'sentiment_raw_{Corpus_Genre}_reference'
  SUBDIR_TEXT_CLEAN = f'text_clean_{Corpus_Genre}_reference'
else:
  SUBDIR_SENTIMENT_RAW = f'sentiment_raw_{Corpus_Genre}_{Corpus_Type}_corpus{Corpus_Number}/'
  SUBDIR_TEXT_CLEAN = f'text_clean_{Corpus_Genre}_{Corpus_Type}_corpus{Corpus_Number}/'

# PATH_SENTIMENT_RAW = f'./sentiment_raw/{SUBDIR_TEXT_RAW}'
# PATH_TEXT_CLEAN = f'./text_clean/{SUBDIR_TEXT_CLEAN}'
PATH_SENTIMENT_RAW = f'./sentiment_raw/{SUBDIR_SENTIMENT_RAW}'
PATH_TEXT_CLEAN = f'./text_clean/{SUBDIR_TEXT_CLEAN}'

# TODO: Clean up
# SUBDIR_TEXT_CLEAN = PATH_TEXT_CLEAN

print(f'PATH_SENTIMENT_RAW:\n  [{PATH_SENTIMENT_RAW}]')
print(f'SUBDIR_SENTIMENT_RAW:\n  [{SUBDIR_SENTIMENT_RAW}]')

print('\n')

print(f'PATH_TEXT_CLEAN:\n  [{PATH_TEXT_CLEAN}]')
print(f'SUBDIR_TEXT_CLEAN:\n  [{SUBDIR_TEXT_CLEAN}]')
# Out:
# Current Working Directory:
# /gdrive/MyDrive/sentimentarcs_notebooks
#
#
# PATH_SENTIMENT_RAW:
#   [./sentiment_raw/sentiment_raw_novels_new_corpus2/]
# SUBDIR_SENTIMENT_RAW:
#   [sentiment_raw_novels_new_corpus2/]
#
#
# PATH_TEXT_CLEAN:
#   [./text_clean/text_clean_novels_new_corpus2/]
# SUBDIR_TEXT_CLEAN:
#   [text_clean_novels_new_corpus2/]

# %% [markdown]
# # **[STEP 2] Automatic Configuration/Setup**

# %%
# Add PATH for ./utils subdirectory

import sys
import os

# !python --version

print('\n')

PATH_UTILS = f'{Path_to_SentimentArcs}utils'
PATH_UTILS

sys.path.append(PATH_UTILS)

print('Contents of Subdirectory [./sentiment_arcs/utils/]\n')
# !ls $PATH_UTILS

# More Specific than PATH for searching libraries
# !echo $PYTHONPATH
# Out:
# Python 3.7.13
#
#
# Contents of Subdirectory [./sentiment_arcs/utils/]
#
# config_matplotlib.py   get_subdirs.py	    sentiment_analysis.py
# config_seaborn.py      global_constants.py  sentiment_arcs_config.py
# file_utils.py	       global_vars.py	    set_globals.py
# get_fullpath.py        __init__.py	    subdir_constants.py
# get_model_families.py  __pycache__	    text_cleaners_new.py
# get_sentimentr.R       read_yaml.py	    text_cleaners.py
# get_sentiments.py      sa_config.py

# %%
# Review Global Variables and set the first few

import global_vars as global_vars

global_vars.SUBDIR_SENTIMENTARCS = Path_to_SentimentArcs
global_vars.Corpus_Genre = Corpus_Genre
global_vars.Corpus_Type = Corpus_Type
global_vars.Corpus_Number = Corpus_Number

global_vars.SUBDIR_SENTIMENT_RAW = SUBDIR_SENTIMENT_RAW
global_vars.PATH_SENTIMENT_RAW = PATH_SENTIMENT_RAW

global_vars.SUBDIR_TEXT_CLEAN = SUBDIR_TEXT_CLEAN
global_vars.PATH_TEXT_CLEAN = PATH_TEXT_CLEAN

dir(global_vars)
# Out:
# ['Corpus_Genre',
#  'Corpus_Number',
#  'Corpus_Type',
#  'FNAME_SENTIMENT_RAW',
#  'MIN_PARAG_LEN',
#  'MIN_SENT_LEN',
#  'NotebookModels',
#  'PATH_SENTIMENT_RAW',
#  'PATH_TEXT_CLEAN',
#  'PATH_TEXT_RAW_CORPUS',
#  'SLANG_DT',
#  'STOPWORDS_ADD_EN',
#  'STOPWORDS_DEL_EN',
#  'SUBDIR_CRUXES',
#  'SUBDIR_DATA',
#  'SUBDIR_GRAPHS',
#  'SUBDIR_SENTIMENTARCS',
#  'SUBDIR_SENTIMENT_CLEAN',
#  'SUBDIR_SENTIMENT_RAW',
#  'SUBDIR_TEXT_CLEAN',
#  'SUBDIR_TEXT_RAW',
#  'SUBDIR_TIMESERIES_CLEAN',
#  'SUBDIR_TIMESERIES_RAW',
#  'SUBDIR_UTILS',
#  'TEST_SENTENCES_LS',
#  'TEST_WORDS_LS',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'corpus_texts_dt',
#  'corpus_titles_dt',
#  'corpus_titles_ls',
#  'lexicons_dt',
#  'model_ensemble_dt',
#  'model_titles_dt']

# %% [markdown]
# ## (each time) Custom Libraries & Define Globals

# %%
# Initialize and clean for each iteration of notebook

# dir(global_vars)

global_vars.corpus_texts_dt = {}
global_vars.corpus_titles_dt = {}

# %%
# Import SentimentArcs Utilities to define Directory Structure
#   based the Selected Corpus Genre, Type and Number

# !pwd 
print('\n')

# from utils import sa_config # .sentiment_arcs_utils
from utils import sa_config

print('Objects in sa_config()')
print(dir(sa_config))
print('\n')

# Directory Structure for the Selected Corpus Genre, Type and Number
sa_config.get_subdirs(Path_to_SentimentArcs, Corpus_Genre, Corpus_Type, Corpus_Number, 'none')
# Out:
# /gdrive/MyDrive/sentimentarcs_notebooks
#
#
# Objects in sa_config()
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'get_subdirs', 'global_vars', 'set_globals']
#
#
# Verify the Directory Structure:
#
# -------------------------------
#
#            [Corpus Genre]: novels
#
#             [Corpus Type]: new
#
#
#     [FNAME_SENTIMENT_RAW]: [NONE]
#
#
#
#
# INPUTS:
# -------------------------------
#
#    [SUBDIR_SENTIMENTARCS]: /gdrive/MyDrive/sentimentarcs_notebooks/
#
#
# STEP 1: Clean Text
# --------------------
#
#         [SUBDIR_TEXT_RAW]: ./text_raw/text_raw_novels_new_corpus2/
#
#       [SUBDIR_TEXT_CLEAN]: ./text_clean/text_clean_novels_new_corpus2/
#
#
# STEP 2: Get Sentiments
# --------------------
#
#    [SUBDIR_SENTIMENT_RAW]: ./sentiment_raw/sentiment_raw_novels_new_corpus2/
#
#  [SUBDIR_SENTIMENT_CLEAN]: ./sentiment_clean/sentiemnt_clean_novels_new_corpus2/
#
#
# STEP 3: Smooth Time Series and Get Crux Points
# --------------------
#
#   [SUBDIR_TIMESERIES_RAW]: ./sentiment_raw/sentiment_raw_novels_new_corpus2/
#
# [SUBDIR_TIMESERIES_CLEAN]: ./sentiment_clean/sentiemnt_clean_novels_new_corpus2/
#
#
#
# OUTPUTS:
# -------------------------------
#
#           [SUBDIR_GRAPHS]: ./graphs/graphs_novels/
#
#             [SUBDIR_DATA]: ./data/data_novels
#
#            [SUBDIR_UTILS]: ./utils/

# %%
# Call SentimentArcs Utility to define Global Variables

sa_config.set_globals()

# Verify sample global var set
print(f'MIN_PARAG_LEN: {global_vars.MIN_PARAG_LEN}')
print(f'STOPWORDS_ADD_EN: {global_vars.STOPWORDS_ADD_EN}')
print(f'TEST_WORDS_LS: {global_vars.TEST_WORDS_LS}')
print(f'SLANG_DT: {global_vars.SLANG_DT}')
# Out:
# MIN_PARAG_LEN: 10
# STOPWORDS_ADD_EN: ['a', 'the', 'an']
# TEST_WORDS_LS: ['Love', 'Hate', 'bizarre', 'strange', 'furious', 'elated', 'curious', 'beserk', 'gambaro']
# SLANG_DT: {'$': ' dollar ', '€': ' euro ', '4ao': 'for adults only', 'a.m': 'before midday', 'a3': 'anytime anywhere anyplace', 'aamof': 'as a matter of fact', 'acct': 'account', 'adih': 'another day in hell', 'afaic': 'as far as i am concerned', 'afaict': 'as far as i can tell', 'afaik': 'as far as i know', 'afair': 'as far as i remember', 'afk': 'away from keyboard', 'app': 'application', 'approx': 'approximately', 'apps': 'applications', 'asap': 'as soon as possible', 'asl': 'age, sex, location', 'atk': 'at the keyboard', 'ave.': 'avenue', 'aymm': 'are you my mother', 'ayor': 'at your own risk', 'b&b': 'bed and breakfast', 'b+b': 'bed and breakfast', 'b.c': 'before christ', 'b2b': 'business to business', 'b2c': 'business to customer', 'b4': 'before', 'b4n': 'bye for now', 'b@u': 'back at you', 'bae': 'before anyone else', 'bak': 'back at keyboard', 'bbbg': 'bye bye be good', 'bbc': 'british broadcasting corporation', 'bbias': 'be back in a second', 'bbl': 'be back later', 'bbs': 'be back soon', 'be4': 'before', 'bfn': 'bye for now', 'blvd': 'boulevard', 'bout': 'about', 'brb': 'be right back', 'bros': 'brothers', 'brt': 'be right there', 'bsaaw': 'big smile and a wink', 'btw': 'by the way', 'bwl': 'bursting with laughter', 'c/o': 'care of', 'cet': 'central european time', 'cf': 'compare', 'cia': 'central intelligence agency', 'csl': 'can not stop laughing', 'cu': 'see you', 'cul8r': 'see you later', 'cv': 'curriculum vitae', 'cwot': 'complete waste of time', 'cya': 'see you', 'cyt': 'see you tomorrow', 'dae': 'does anyone else', 'dbmib': 'do not bother me i am busy', 'diy': 'do it yourself', 'dm': 'direct message', 'dwh': 'during work hours', 'e123': 'easy as one two three', 'eet': 'eastern european time', 'eg': 'example', 'embm': 'early morning business meeting', 'encl': 'enclosed', 'encl.': 'enclosed', 'etc': 'and so on', 'faq': 'frequently asked questions', 'fawc': 'for anyone who cares', 'fb': 'facebook', 'fc': 'fingers crossed', 'fig': 'figure', 'fimh': 'forever in my heart', 'ft.': 'feet', 'ft': 'featuring', 'ftl': 'for the loss', 'ftw': 'for the win', 'fwiw': 'for what it is worth', 'fyi': 'for your information', 'g9': 'genius', 'gahoy': 'get a hold of yourself', 'gal': 'get a life', 'gcse': 'general certificate of secondary education', 'gfn': 'gone for now', 'gg': 'good game', 'gl': 'good luck', 'glhf': 'good luck have fun', 'gmt': 'greenwich mean time', 'gmta': 'great minds think alike', 'gn': 'good night', 'g.o.a.t': 'greatest of all time', 'goat': 'greatest of all time', 'goi': 'get over it', 'gps': 'global positioning system', 'gr8': 'great', 'gratz': 'congratulations', 'gyal': 'girl', 'h&c': 'hot and cold', 'hp': 'horsepower', 'hr': 'hour', 'hrh': 'his royal highness', 'ht': 'height', 'ibrb': 'i will be right back', 'ic': 'i see', 'icq': 'i seek you', 'icymi': 'in case you missed it', 'idc': 'i do not care', 'idgadf': 'i do not give a damn fuck', 'idgaf': 'i do not give a fuck', 'idk': 'i do not know', 'ie': 'that is', 'i.e': 'that is', 'ifyp': 'i feel your pain', 'IG': 'instagram', 'iirc': 'if i remember correctly', 'ilu': 'i love you', 'ily': 'i love you', 'imho': 'in my humble opinion', 'imo': 'in my opinion', 'imu': 'i miss you', 'iow': 'in other words', 'irl': 'in real life', 'j4f': 'just for fun', 'jic': 'just in case', 'jk': 'just kidding', 'jsyk': 'just so you know', 'l8r': 'later', 'lb': 'pound', 'lbs': 'pounds', 'ldr': 'long distance relationship', 'lmao': 'laugh my ass off', 'lmfao': 'laugh my fucking ass off', 'lol': 'laughing out loud', 'ltd': 'limited', 'ltns': 'long time no see', 'm8': 'mate', 'mf': 'motherfucker', 'mfs': 'motherfuckers', 'mfw': 'my face when', 'mofo': 'motherfucker', 'mph': 'miles per hour', 'mr': 'mister', 'mrw': 'my reaction when', 'ms': 'miss', 'mte': 'my thoughts exactly', 'nagi': 'not a good idea', 'nbc': 'national broadcasting company', 'nbd': 'not big deal', 'nfs': 'not for sale', 'ngl': 'not going to lie', 'nhs': 'national health service', 'nrn': 'no reply necessary', 'n ...

# %% [markdown]
# ## Configure Jupyter Notebook

# %%
# Configure Jupyter

# To reload modules under development

# Option (a)
# %load_ext autoreload
# %autoreload 2
# Option (b)
# import importlib
# importlib.reload(functions.readfunctions)


# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Enable multiple outputs from one code cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from IPython.display import display
from IPython.display import Image
from ipywidgets import widgets, interactive

import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# ## (each time) Read YAML Configuration for Corpus and Models

# %%
# from utils import sa_config # .sentiment_arcs_utils

import yaml

from utils import read_yaml

print('Objects in read_yaml()')
print(dir(read_yaml))
print('\n')

# Directory Structure for the Selected Corpus Genre, Type and Number
read_yaml.read_corpus_yaml(Corpus_Genre, Corpus_Type, Corpus_Number)

print('SentimentArcs Model Ensemble ------------------------------\n')
model_titles_ls = global_vars.models_titles_dt.keys()
print('\n'.join(model_titles_ls))


print('\n\nCorpus Texts ------------------------------\n')
corpus_titles_ls = list(global_vars.corpus_titles_dt.keys())
print('\n'.join(corpus_titles_ls))


print(f'\n\nThere are {len(model_titles_ls)} Models in the SentimentArcs Ensemble above.\n')
print(f'\nThere are {len(corpus_titles_ls)} Texts in the Corpus above.\n')
print('\n')

global_vars.corpus_titles_dt
# Out:
# Objects in read_yaml()
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'global_vars', 'read_corpus_yaml', 'yaml']
#
#
# YAML Directory: text_raw/text_raw_novels_new_corpus2
# YAML File: text_raw_novels_new_corpus2_info.yaml
# SentimentArcs Model Ensemble ------------------------------
#
# AutoGluon_Text
# BERT_2IMDB
# BERT_Dual_Coding
# BERT_Multilingual
# BERT_Yelp
# CNN_DNN
# Distilled_BERT
# FLAML_AutoML
# Fully_Connected_Network
# HyperOpt_CNN_Flair_AutoML
# LSTM_DNN
# Logistic_Regression
# Logistic_Regression_CV
# Multilingual_CNN_Stanza_AutoML
# Multinomial_Naive_Bayes
# Pattern
# Random_Forest
# RoBERTa_Large_15DB
# RoBERTa_XML_8Language
# FinBERT
# FinBERT_Tone
# DistilRoBERTa_FinNews
# SentimentR_JockersRinker
# SentimentR_Jockers
# SentimentR_Bing
# SentimentR_NRC
# SentimentR_SentiWord
# SentimentR_SenticNet
# SentimentR_LMcD
# SentimentR_SentimentR
# PySentimentR_JockersRinker
# PySentimentR_Huliu
# PySentimentR_NRC
# PySentimentR_SentiWord
# PySentimentR_SenticNet
# PySentimentR_LMcD
# SyuzhetR_AFINN
# SyuzhetR_Bing
# SyuzhetR_NRC
# SyuzhetR_SyuzhetR
# T5_IMDB
# TextBlob
# VADER
# AFINN
# XGBoost
#
#
# Corpus Texts ------------------------------
#
# tmorrison_songofsolomon
# cliu_threebodyproblem
# sking_doctorsleep
#
#
# There are 45 Models in the SentimentArcs Ensemble above.
#
#
# There are 3 Texts in the Corpus above.
# {'cliu_threebodyproblem': ['The Three Body Problem by Cixin Liu', 2008, 0],
#  'sking_doctorsleep': ['Doctor Sleep by Stphen King', 2013, 0],
#  'tmorrison_songofsolomon': ['Song of Solomon by Toni Morrison', 1977, 0]}

# %% [markdown]
# ## Install Libraries: R

# %%
# !pip install rpy2

# %%
# !pip install -U rpy2

# %%
# Load Jupyter rpy2 Extension  
#   enables the %%R magic commands

# %load_ext rpy2.ipython

# %reload_ext rpy2.ipython
# Out:
# 2022-04-16 11:34:56,266 : INFO : NumExpr defaulting to 2 threads.

# %%
# %%time 
# %%capture 
# %%R

# Install Syuzhet.R, Sentiment.R and Utility Libraries

# NOTE: 1m12s 
#       1m05s

#       1m13s 00:47 @20220406Wed Novels Corpus1 2 Novels

install.packages(c('syuzhet', 'sentimentr', 'tidyverse', 'lexicon'))

library(syuzhet)
library(sentimentr)
library(tidyverse)
library(lexicon)
# Out:
# 2022-04-16 11:34:56,701 : WARNING : R[write to console]: Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# 2022-04-16 11:34:57,903 : WARNING : R[write to console]: also installing the dependencies ‘slam’, ‘english’, ‘mgsub’, ‘qdapRegex’, ‘textshape’, ‘NLP’, ‘zoo’, ‘dtt’, ‘textclean’
#
#
# 2022-04-16 11:34:57,911 : WARNING : R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/slam_0.1-50.tar.gz'
#
# 2022-04-16 11:34:58,079 : WARNING : R[write to console]: Content type 'application/x-gzip'
# 2022-04-16 11:34:58,082 : WARNING : R[write to console]:  length 53641 bytes (52 KB)
#
# 2022-04-16 11:34:58,084 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,087 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,089 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,090 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,091 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,092 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,094 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,095 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,096 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,097 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,099 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,100 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,101 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,103 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,104 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,105 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,107 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,108 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,109 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,110 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,112 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,113 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,114 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,116 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,117 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,118 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,119 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,121 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,122 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,123 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,124 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,126 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,127 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,128 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,130 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,131 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,132 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,133 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,135 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,136 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,137 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,138 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,139 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,140 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,142 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,144 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,145 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,146 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,147 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,148 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,150 : WARNING : R[write to console]:
#
# 2022-04-16 11:34:58,151 : WARNING : R[write to console]: downloaded 52 KB
#
#
# 2022-04-16 11:34:58,157 : WARNING : R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/english_1.2-6.tar.gz'
#
# 2022-04-16 11:34:58,323 : WARNING : R[write to console]: Content type 'application/x-gzip'
# 2022-04-16 11:34:58,324 : WARNING : R[write to console]:  length 103235 bytes (100 KB)
#
# 2022-04-16 11:34:58,330 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,331 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,333 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,334 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,335 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,337 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,338 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,339 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,341 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,342 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,343 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,345 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,346 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,347 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,348 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,350 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,352 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,353 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,354 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,355 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,357 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,358 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,359 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,360 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,362 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,363 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,364 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,366 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,368 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,370 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,371 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,373 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,374 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,375 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,377 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,378 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,381 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,382 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,384 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,385 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,387 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,388 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,389 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,391 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,392 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,393 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,395 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,396 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,398 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,399 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,400 : WARNING : R[write to console]:
#
# 2022-04-16 11:34:58,402 : WARNING : R[write to console]: downloaded 100 KB
#
#
# 2022-04-16 11:34:58,409 : WARNING : R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/mgsub_1.7.3.tar.gz'
#
# 2022-04-16 11:34:58,578 : WARNING : R[write to console]: Content type 'application/x-gzip'
# 2022-04-16 11:34:58,582 : WARNING : R[write to console]:  length 20292 bytes (19 KB)
#
# 2022-04-16 11:34:58,583 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,584 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,586 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,587 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,588 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,590 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,591 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,593 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,594 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,595 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,597 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,599 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,600 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,602 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,603 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,604 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,607 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,609 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,610 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,612 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,614 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,616 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,617 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,619 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,621 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,622 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,624 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,626 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,628 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,629 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,631 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,633 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,634 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,636 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,637 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,638 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,640 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,643 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,644 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,646 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,648 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,650 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,651 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,652 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,654 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,655 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,657 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,659 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,661 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,662 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,664 : WARNING : R[write to console]:
#
# 2022-04-16 11:34:58,666 : WARNING : R[write to console]: downloaded 19 KB
#
#
# 2022-04-16 11:34:58,680 : WARNING : R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/qdapRegex_0.7.2.tar.gz'
#
# 2022-04-16 11:34:58,848 : WARNING : R[write to console]: Content type 'application/x-gzip'
# 2022-04-16 11:34:58,850 : WARNING : R[write to console]:  length 149638 bytes (146 KB)
#
# 2022-04-16 11:34:58,852 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,853 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,855 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,857 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,858 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,860 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,862 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,864 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,865 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,867 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,868 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,869 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,872 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,874 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,875 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,877 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,879 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,880 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,881 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,883 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,884 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,887 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,888 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,890 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,891 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,893 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,894 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,896 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,897 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,898 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,899 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,902 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,904 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,905 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,907 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,908 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,909 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,911 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,912 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,913 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,914 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,916 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,917 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,918 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,920 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,921 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,922 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,923 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,925 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,926 : WARNING : R[write to console]: =
# 2022-04-16 11:34:58,927 : WARNING : R[write to console]:
#
# 2022-04-16 11:34:58,928 : WARNING : R[write to console]: downloaded 146 KB
#
#
# 2022-04-16 11:34:58,934 : WARNING : R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/textshape_1.7.3.tar.gz'
#
# 2022-04-16 11:34:59,114 : WARNING : R[write to console]: Content type 'application/x-gzip'
# 2022-04-16 11:34:59,116 : WARNING : R[write to console]:  length 697969 bytes (681 KB)
#
# 2022-04-16 11:34:59,118 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,120 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,126 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,127 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,129 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,137 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,138 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,139 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,141 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,143 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,144 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,145 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,146 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,148 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,149 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,150 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,151 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,153 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,154 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,155 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,159 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,160 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,161 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,162 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,164 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,165 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,166 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,167 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,169 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,170 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,171 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,172 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,173 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,175 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,176 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,177 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,178 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,181 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,183 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,184 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,185 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,186 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,187 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,189 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,190 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,192 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,193 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,194 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,195 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,197 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,198 : WARNING : R[write to console]:
#
# 2022-04-16 11:34:59,199 : WARNING : R[write to console]: downloaded 681 KB
#
#
# 2022-04-16 11:34:59,205 : WARNING : R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/NLP_0.2-1.tar.gz'
#
# 2022-04-16 11:34:59,373 : WARNING : R[write to console]: Content type 'application/x-gzip'
# 2022-04-16 11:34:59,380 : WARNING : R[write to console]:  length 144368 bytes (140 KB)
#
# 2022-04-16 11:34:59,385 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,389 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,391 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,394 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,398 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,402 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,411 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,415 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,418 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,419 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,420 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,422 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,423 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,427 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,429 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,430 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,433 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,434 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,436 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,437 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,439 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,448 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,449 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,451 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,452 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,454 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,455 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,456 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,457 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,458 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,460 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,461 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,462 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,463 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,464 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,466 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,467 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,468 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,469 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,470 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,472 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,473 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,474 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,475 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,476 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,479 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,480 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,482 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,483 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,484 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,485 : WARNING : R[write to console]:
#
# 2022-04-16 11:34:59,487 : WARNING : R[write to console]: downloaded 140 KB
#
#
# 2022-04-16 11:34:59,492 : WARNING : R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/zoo_1.8-10.tar.gz'
#
# 2022-04-16 11:34:59,645 : WARNING : R[write to console]: Content type 'application/x-gzip'
# 2022-04-16 11:34:59,647 : WARNING : R[write to console]:  length 808943 bytes (789 KB)
#
# 2022-04-16 11:34:59,648 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,657 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,658 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,661 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,664 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,669 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,671 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,674 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,676 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,677 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,679 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,680 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,682 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,683 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,685 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,687 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,688 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,692 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,693 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,695 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,698 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,700 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,702 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,703 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,705 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,707 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,708 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,709 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,711 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,715 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,717 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,719 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,720 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,723 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,724 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,726 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,727 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,728 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,730 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,734 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,736 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,739 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,741 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,743 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,745 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,747 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,748 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,750 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,751 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,753 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,757 : WARNING : R[write to console]:
#
# 2022-04-16 11:34:59,758 : WARNING : R[write to console]: downloaded 789 KB
#
#
# 2022-04-16 11:34:59,763 : WARNING : R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/dtt_0.1-2.tar.gz'
#
# 2022-04-16 11:34:59,934 : WARNING : R[write to console]: Content type 'application/x-gzip'
# 2022-04-16 11:34:59,936 : WARNING : R[write to console]:  length 3146 bytes
#
# 2022-04-16 11:34:59,939 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,942 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,946 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,947 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,948 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,949 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,951 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,953 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,954 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,956 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,957 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,958 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,959 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,961 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,962 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,963 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,964 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,966 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,967 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,968 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,969 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,972 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,973 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,974 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,975 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,976 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,977 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,981 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,982 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,984 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,985 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,986 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,987 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,988 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,990 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,991 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,992 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,993 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,994 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,996 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,997 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,998 : WARNING : R[write to console]: =
# 2022-04-16 11:34:59,999 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,000 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,002 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,003 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,004 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,005 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,006 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,008 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,009 : WARNING : R[write to console]:
#
# 2022-04-16 11:35:00,010 : WARNING : R[write to console]: downloaded 3146 bytes
#
#
# 2022-04-16 11:35:00,015 : WARNING : R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/textclean_0.9.3.tar.gz'
#
# 2022-04-16 11:35:00,185 : WARNING : R[write to console]: Content type 'application/x-gzip'
# 2022-04-16 11:35:00,186 : WARNING : R[write to console]:  length 1131554 bytes (1.1 MB)
#
# 2022-04-16 11:35:00,191 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,197 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,201 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,209 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,211 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,213 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,215 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,217 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,220 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,222 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,224 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,226 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,228 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,229 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,233 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,236 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,238 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,241 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,245 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,246 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,248 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,249 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,251 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,252 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,255 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,256 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,258 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,261 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,265 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,266 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,268 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,271 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,273 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,276 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,277 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,281 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,282 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,285 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,289 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,291 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,292 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,293 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,295 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,297 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,298 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,299 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,301 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,302 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,306 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,308 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,309 : WARNING : R[write to console]:
#
# 2022-04-16 11:35:00,310 : WARNING : R[write to console]: downloaded 1.1 MB
#
#
# 2022-04-16 11:35:00,315 : WARNING : R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/syuzhet_1.0.6.tar.gz'
#
# 2022-04-16 11:35:00,486 : WARNING : R[write to console]: Content type 'application/x-gzip'
# 2022-04-16 11:35:00,487 : WARNING : R[write to console]:  length 3059075 bytes (2.9 MB)
#
# 2022-04-16 11:35:00,500 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,511 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,517 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,521 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,525 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,528 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,532 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,534 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,537 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,538 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,540 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,542 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,543 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,545 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,547 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,549 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,552 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,554 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,557 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,561 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,563 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,566 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,568 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,570 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,573 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,575 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,577 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,579 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,582 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,587 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,588 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,590 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,592 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,594 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,597 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,598 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,600 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,603 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,605 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,607 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,610 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,612 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,616 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,618 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,619 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,621 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,622 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,624 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,627 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,629 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,632 : WARNING : R[write to console]:
#
# 2022-04-16 11:35:00,633 : WARNING : R[write to console]: downloaded 2.9 MB
#
#
# 2022-04-16 11:35:00,641 : WARNING : R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/sentimentr_2.9.0.tar.gz'
#
# 2022-04-16 11:35:00,825 : WARNING : R[write to console]: Content type 'application/x-gzip'
# 2022-04-16 11:35:00,827 : WARNING : R[write to console]:  length 3851533 bytes (3.7 MB)
#
# 2022-04-16 11:35:00,846 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,855 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,860 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,865 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,869 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,872 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,875 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,877 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,879 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,881 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,882 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,884 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,886 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,889 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,890 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,893 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,895 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,896 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,898 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,900 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,902 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,906 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,909 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,911 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,912 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,916 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,918 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,919 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,922 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,924 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,927 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,929 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,931 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,933 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,935 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,940 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,943 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,946 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,948 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,949 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,951 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,952 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,954 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,956 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,958 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,960 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,963 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,964 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,966 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,968 : WARNING : R[write to console]: =
# 2022-04-16 11:35:00,969 : WARNING : R[write to console]:
#
# 2022-04-16 11:35:00,971 : WARNING : R[write to console]: downloaded 3.7 MB
#
#
# 2022-04-16 11:35:00,979 : WARNING : R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/tidyverse_1.3.1.tar.gz'
#
# 2022-04-16 11:35:01,128 : WARNING : R[write to console]: Content type 'application/x-gzip'
# 2022-04-16 11:35:01,130 : WARNING : R[write to console]:  length 702779 bytes (686 KB)
#
# 2022-04-16 11:35:01,132 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,135 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,141 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,142 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,146 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,152 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,155 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,156 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,161 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,162 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,163 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,164 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,166 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,167 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,171 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,172 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,175 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,176 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,182 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,184 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,185 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,187 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,189 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,191 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,192 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,193 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,196 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,198 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,200 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,203 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,204 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,206 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,209 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,211 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,212 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,213 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,218 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,220 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,221 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,222 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,228 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,230 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,231 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,233 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,234 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,236 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,238 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,240 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,241 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,243 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,245 : WARNING : R[write to console]:
#
# 2022-04-16 11:35:01,247 : WARNING : R[write to console]: downloaded 686 KB
#
#
# 2022-04-16 11:35:01,256 : WARNING : R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/lexicon_1.2.1.tar.gz'
#
# 2022-04-16 11:35:01,435 : WARNING : R[write to console]: Content type 'application/x-gzip'
# 2022-04-16 11:35:01,437 : WARNING : R[write to console]:  length 2516233 bytes (2.4 MB)
#
# 2022-04-16 11:35:01,449 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,462 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,467 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,473 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,476 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,481 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,483 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,486 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,487 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,490 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,492 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,494 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,496 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,498 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,500 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,502 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,503 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,505 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,507 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,509 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,515 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,517 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,520 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,522 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,526 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,527 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,529 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,531 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,533 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,535 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,540 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,541 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,543 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,545 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,547 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,549 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,550 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,552 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,554 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,556 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,562 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,564 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,565 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,567 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,569 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,571 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,573 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,575 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,577 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,582 : WARNING : R[write to console]: =
# 2022-04-16 11:35:01,583 : WARNING : R[write to console]:
#
# 2022-04-16 11:35:01,585 : WARNING : R[write to console]: downloaded 2.4 MB
#
#
# 2022-04-16 11:36:07,030 : WARNING : R[write to console]:
#
# 2022-04-16 11:36:07,033 : WARNING : R[write to console]:
# 2022-04-16 11:36:07,036 : WARNING : R[write to console]: The downloaded source packages are in
# 	‘/tmp/Rtmp6TJlb5/downloaded_packages’
# 2022-04-16 11:36:07,040 : WARNING : R[write to console]:
# 2022-04-16 11:36:07,041 : WARNING : R[write to console]:
#
# 2022-04-16 11:36:07,382 : WARNING : R[write to console]:
# Attaching package: ‘sentimentr’
#
#
# 2022-04-16 11:36:07,387 : WARNING : R[write to console]: The following object is masked from ‘package:syuzhet’:
#
#     get_sentences
#
#
# 2022-04-16 11:36:08,575 : WARNING : R[write to console]: ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# 2022-04-16 11:36:08,587 : WARNING : R[write to console]: ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.6     ✔ dplyr   1.0.8
# ✔ tidyr   1.2.0     ✔ stringr 1.4.0
# ✔ readr   2.1.2     ✔ forcats 0.5.1
#
# 2022-04-16 11:36:08,704 : WARNING : R[write to console]: ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# 2022-04-16 11:36:08,719 : WARNING : R[write to console]:
# Attaching package: ‘lexicon’
#
#
# 2022-04-16 11:36:08,722 : WARNING : R[write to console]: The following object is masked from ‘package:sentimentr’:
#
#     available_data
# CPU times: user 4.49 s, sys: 456 ms, total: 4.94 s
# Wall time: 1min 12s

# %%
# Load Python libraries to exchange data with R Program Space and read R Datafiles

import rpy2.robjects as robjects
from rpy2.robjects.packages import importr

# %%
# %%R
#
# # Verify R in Kernel Version
# # R.version.string
#
# # Verfiy R Kernel Environment
# # Sys.getenv
#
# # Verify R Kernel Session Info
# sessionInfo()
# Out:
# R version 4.1.3 (2022-03-10)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: Ubuntu 18.04.5 LTS
#
# Matrix products: default
# BLAS:   /usr/lib/x86_64-linux-gnu/openblas/libblas.so.3
# LAPACK: /usr/lib/x86_64-linux-gnu/openblas/liblapack.so.3
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] tools     stats     graphics  grDevices utils     datasets  methods
# [8] base
#
# other attached packages:
#  [1] lexicon_1.2.1    forcats_0.5.1    stringr_1.4.0    dplyr_1.0.8
#  [5] purrr_0.3.4      readr_2.1.2      tidyr_1.2.0      tibble_3.1.6
#  [9] ggplot2_3.3.5    tidyverse_1.3.1  sentimentr_2.9.0 syuzhet_1.0.6
#
# loaded via a namespace (and not attached):
#  [1] cellranger_1.1.0  pillar_1.7.0      compiler_4.1.3    dbplyr_2.1.1
#  [5] lubridate_1.8.0   jsonlite_1.8.0    lifecycle_1.0.1   gtable_0.3.0
#  [9] pkgconfig_2.0.3   rlang_1.0.2       reprex_2.0.1      rstudioapi_0.13
# [13] cli_3.2.0         DBI_1.1.2         haven_2.4.3       xml2_1.3.3
# [17] withr_2.5.0       httr_1.4.2        fs_1.5.2          hms_1.1.1
# [21] generics_0.1.2    vctrs_0.4.0       grid_4.1.3        tidyselect_1.1.2
# [25] glue_1.6.2        data.table_1.14.2 R6_2.5.1          qdapRegex_0.7.2
# [29] fansi_1.0.3       readxl_1.4.0      textclean_0.9.3   tzdb_0.3.0
# [33] modelr_0.1.8      magrittr_2.0.3    backports_1.4.1   scales_1.1.1
# [37] ellipsis_0.3.2    rvest_1.0.2       assertthat_0.2.1  colorspace_2.0-3
# [41] utf8_1.2.2        stringi_1.7.6     munsell_0.5.0     broom_0.7.12
# [45] crayon_1.5.1

# %% [markdown]
# ## Install Libraries: Python

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

from glob import glob
import copy
import json # Installed above in YAML Configuration Section

# %% [markdown]
# ## Setup Matplotlib Style
#
# * https://matplotlib.org/stable/tutorials/introductory/customizing.html

# %%
# Configure Matplotlib

# View available styles
# plt.style.available

# Verify in SentimentArcs Root Directory
os.chdir(Path_to_SentimentArcs)

# %run -i './utils/config_matplotlib.py'

config_matplotlib()

print('Matplotlib Configuration ------------------------------')
print('\n  (Uncomment to view)')
# plt.rcParams.keys()
print('\n  Edit ./utils/config_matplotlib.py to change')
# Out:
#  New figure size:  (20, 10)
# Matplotlib Configuration ------------------------------
#
#   (Uncomment to view)
#
#   Edit ./utils/config_matplotlib.py to change

# %%
"""
from cycler import cycler

colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']   
linestyles = ['-', '--', ':', '-.','-', '--', ':', '-.','-', '--']

cycle = plt.cycler("color", colors) + plt.cycler("linestyle", linestyles)

# View previous matplotlib configuration
print('\n Old Matplotlib Configurtion Settings:\n')
# plt.rc.show
print('\n\n')

# Update and view new matplotlib configuration
print('\n New Matplotlib Configurtion Settings:\n')
myparams = {'axes.prop_cycle': cycle}
plt.rcParams.update(myparams)

plt.rcParams["axes.titlesize"] = 16
plt.rcParams['figure.figsize'] = 20,10
plt.rcParams["legend.fontsize"] = 10
plt.rcParams["xtick.labelsize"] = 12
plt.rcParams["ytick.labelsize"] = 12
plt.rcParams["axes.labelsize"] = 12

# Set matplotlib plot figure.figsize

new_plt_size = plt.rcParams["figure.figsize"]=(20,10)

print(" New figure size: ",new_plt_size)
""";

# %% [markdown]
# ## Setup Seaborn Style

# %%
# Configure Seaborn

# Verify in SentimentArcs Root Directory
os.chdir(Path_to_SentimentArcs)

# %run -i './utils/config_seaborn.py'

config_seaborn()

print('Seaborn Configuration ------------------------------\n')
# print('\n  Update ./utils/config_seaborn.py to display seaborn settings')

"""
# Seaborn: Set Context
# sns.set_context("notebook")

# Seaborn: Set Theme (Scale of Font)
sns.set_theme('paper')  # paper, notebook, talk, poster

# Seaborn: Set Style
# sns.set_style('ticks') # darkgrid, whitegrid, dark, white, and ticks
plt.style.use('seaborn-whitegrid')

# sns.set_palette('tab10')
# sns.color_palette()

# sns.set_palette('tab10')
# sns.color_palette()
""";
# Out:
# Seaborn Configuration ------------------------------

# %%
"""
# Configure Seaborn

# Verify in SentimentArcs Root Directory
os.chdir(Path_to_SentimentArcs)

# %run -i './utils/config_seaborn.py'

config_seaborn()

print('Seaborn Configuration ------------------------------\n')
# print('\n  Update ./utils/config_seaborn.py to display seaborn settings')
# View previous seaborn configuration
print('\n Old Seaborn Configurtion Settings:\n')
sns.axes_style()
print('\n\n')

# Update and View new seaborn configuration
print('\n New Seaborn Configurtion Settings:\n')
# sns.set_style('white')
sns.set_context('paper')
sns.set_style('white')
sns.set_palette('tab10')

# Change defaults
# sns.set(style='white', context='talk', palette='tab10')
""";

# %% [markdown]
# ## Python Utility Functions

# %% [markdown]
# ### (each time) Generate Convenient Data Lists

# %%
# Derive List of Texts in Corpus a)keys and b)full author and titles

print('Dictionary: corpus_titles_dt')
global_vars.corpus_titles_dt
print('\n')

corpus_texts_ls = list(global_vars.corpus_titles_dt.keys())
print(f'\nCorpus Texts:')
for akey in corpus_texts_ls:
  print(f'  {akey}')
print('\n')

print(f'\nNatural Corpus Titles:')
corpus_titles_ls = [x[0] for x in list(global_vars.corpus_titles_dt.values())]
for akey in corpus_titles_ls:
  print(f'  {akey}')
# Out:
# Dictionary: corpus_titles_dt
# {'cliu_threebodyproblem': ['The Three Body Problem by Cixin Liu', 2008, 0],
#  'sking_doctorsleep': ['Doctor Sleep by Stphen King', 2013, 0],
#  'tmorrison_songofsolomon': ['Song of Solomon by Toni Morrison', 1977, 0]}
# Corpus Texts:
#   tmorrison_songofsolomon
#   cliu_threebodyproblem
#   sking_doctorsleep
#
#
#
# Natural Corpus Titles:
#   Song of Solomon by Toni Morrison
#   The Three Body Problem by Cixin Liu
#   Doctor Sleep by Stphen King

# %%
# Get Model Families of Ensemble

from utils.get_model_families import get_ensemble_model_famalies

global_vars.models_ensemble_dt = get_ensemble_model_famalies(global_vars.models_titles_dt)

print('\nTest: Lexicon Family of Models:')
global_vars.models_ensemble_dt['lexicon']
# Out:
# There are 12 Lexicon Models
#   Lexicon Model #0: sentimentr_sentimentr
#   Lexicon Model #1: pysentimentr_jockersrinker
#   Lexicon Model #2: pysentimentr_huliu
#   Lexicon Model #3: pysentimentr_nrc
#   Lexicon Model #4: pysentimentr_sentiword
#   Lexicon Model #5: pysentimentr_senticnet
#   Lexicon Model #6: pysentimentr_lmcd
#   Lexicon Model #7: syuzhetr_afinn
#   Lexicon Model #8: syuzhetr_bing
#   Lexicon Model #9: syuzhetr_nrc
#   Lexicon Model #10: syuzhetr_syuzhetr
#   Lexicon Model #11: afinn
#
# There are 9 Heuristic Models
#   Heuristic Model #0: pattern
#   Heuristic Model #1: sentimentr_jockersrinker
#   Heuristic Model #2: sentimentr_jockers
#   Heuristic Model #3: sentimentr_bing
#   Heuristic Model #4: sentimentr_nrc
#   Heuristic Model #5: sentimentr_sentiword
#   Heuristic Model #6: sentimentr_senticnet
#   Heuristic Model #7: sentimentr_lmcd
#   Heuristic Model #8: vader
#
# There are 8 Traditional ML Models
#   Traditional ML Model #0: autogluon
#   Traditional ML Model #1: flaml
#   Traditional ML Model #2: logreg
#   Traditional ML Model #3: logreg_cv
#   Traditional ML Model #4: multinb
#   Traditional ML Model #5: rf
#   Traditional ML Model #6: textblob
#   Traditional ML Model #7: xgb
#
# There are 5 DNN Models
#   DNN Model #0: cnn
#   DNN Model #1: fcn
#   DNN Model #2: flair
#   DNN Model #3: lstm
#   DNN Model #4: stanza
#
# There are 11 Transformer Models
#   Transformer Model #0: imdb2way
#   Transformer Model #1: hinglish
#   Transformer Model #2: nlptown
#   Transformer Model #3: yelp
#   Transformer Model #4: huggingface
#   Transformer Model #5: roberta15lg
#   Transformer Model #6: robertaxml8lang
#   Transformer Model #7: finbert
#   Transformer Model #8: finberttone
#   Transformer Model #9: distilrobertafinnews
#   Transformer Model #10: t5imdb50k
#
# There are 5 Total Models:
#   Model # 0: lexicon
#   Model # 1: heuristic
#   Model # 2: ml
#   Model # 3: dnn
#   Model # 4: transformer
#
# There are 5 Total Models (+1 for Ensemble Mean)
#
# Test: Lexicon Family of Models:
# ['sentimentr_sentimentr',
#  'pysentimentr_jockersrinker',
#  'pysentimentr_huliu',
#  'pysentimentr_nrc',
#  'pysentimentr_sentiword',
#  'pysentimentr_senticnet',
#  'pysentimentr_lmcd',
#  'syuzhetr_afinn',
#  'syuzhetr_bing',
#  'syuzhetr_nrc',
#  'syuzhetr_syuzhetr',
#  'afinn']

# %% [markdown]
# ### File Functions

# %%
# Verify in SentimentArcs Root Directory
os.chdir(Path_to_SentimentArcs)

# %run -i './utils/file_utils.py'
# from utils.file_utils import *

# %run -i './utils/file_utils.py'

# TODO: Not used? Delete?
# get_fullpath(text_title_str, ftype='data_clean', fig_no='', first_note = '',last_note='', plot_ext='png', no_date=False)

# %% [markdown]
# # **[STEP 3] Read all Preprocessed Novels**

# %%
# !ls {Path_to_SentimentArcs}{PATH_TEXT_CLEAN}
# Out:
# cliu_threebodyproblem.csv  sking_doctorsleep.csv  tmorrison_songofsolomon.csv

# %%
# Verify cwd and subdir of Cleaned Corpus Texts

print('Current Working Directory:')
# !pwd

print(f'\nSubdir with all Cleaned Texts of Corpus:\n  {SUBDIR_TEXT_CLEAN}')

print(f'\n\nFilenames of Cleaned Texts:\n')
# !ls -1 {Path_to_SentimentArcs}{PATH_TEXT_CLEAN}
# Out:
# Current Working Directory:
# /gdrive/MyDrive/sentimentarcs_notebooks
#
# Subdir with all Cleaned Texts of Corpus:
#   text_clean_novels_new_corpus2/
#
#
# Filenames of Cleaned Texts:
#
# cliu_threebodyproblem.csv
# sking_doctorsleep.csv
# tmorrison_songofsolomon.csv

# %%
# Create a List (preprocessed_ls) of all preprocessed text files

# Verify in SentimentArcs Root Directory
os.chdir(Path_to_SentimentArcs)

try:
    preprocessed_ls = glob(f'{PATH_TEXT_CLEAN}/*.csv')
    preprocessed_ls = [x.split('/')[-1] for x in preprocessed_ls]
    preprocessed_ls = [x.split('.')[0] for x in preprocessed_ls]
except IndexError:
    raise RuntimeError('No csv file found')

print('\n'.join(preprocessed_ls))
print('\n')
print(f'Found {len(preprocessed_ls)} Preprocessed files in {SUBDIR_TEXT_CLEAN}')
# Out:
# cliu_threebodyproblem
# sking_doctorsleep
# tmorrison_songofsolomon
#
#
# Found 3 Preprocessed files in text_clean_novels_new_corpus2/

# %%
# Read all preprocessed text files into master DataFrame (corpus_dt)

corpus_texts_dt = {}

for i,atext in enumerate(preprocessed_ls):
  print(f'Processing #{i}: {atext}...')
  afile_fullpath = f'{PATH_TEXT_CLEAN}/{atext}.csv'
  print(f'               {afile_fullpath}')
  atext_df = pd.read_csv(afile_fullpath, index_col=[0])
  corpus_texts_dt[atext] = atext_df
# Out:
# Processing #0: cliu_threebodyproblem...
#                ./text_clean/text_clean_novels_new_corpus2//cliu_threebodyproblem.csv
# Processing #1: sking_doctorsleep...
#                ./text_clean/text_clean_novels_new_corpus2//sking_doctorsleep.csv
# Processing #2: tmorrison_songofsolomon...
#                ./text_clean/text_clean_novels_new_corpus2//tmorrison_songofsolomon.csv

# %%
# Verify the Text read into master Dictionary of DataFrames

corpus_texts_dt.keys()
print('\n')
print(f'There were {len(corpus_texts_dt)} preprocessed Text read into the Dict corpus_texts_dt')
# Out:
# dict_keys(['cliu_threebodyproblem', 'sking_doctorsleep', 'tmorrison_songofsolomon'])
# There were 3 preprocessed Text read into the Dict corpus_texts_dt

# %%
# Check if there are any Null strings in the text_clean columns

for i, atext in enumerate(list(corpus_texts_dt.keys())):
  print(f'\nNovel #{i}: {atext}')
  nan_ct = corpus_texts_dt[atext].text_clean.isna().sum()
  if nan_ct > 0:
    print(f'      {nan_ct} Null strings in the text_clean column')
# Out:
# Novel #0: cliu_threebodyproblem
#       5 Null strings in the text_clean column
#
# Novel #1: sking_doctorsleep
#       76 Null strings in the text_clean column
#
# Novel #2: tmorrison_songofsolomon

# %%
# Fill in all the Null value of text_clean with placeholder 'empty_string'

for i, atext in enumerate(list(corpus_texts_dt.keys())):
  # print(f'Novel #{i}: {atext}')
  # Fill all text_clean == Null with 'empty_string' so sentimentr::sentiment doesn't break
  corpus_texts_dt[atext][corpus_texts_dt[atext].text_clean.isna()] = 'empty_string'

# %%
# Verify DataFrame of first Text in Corpus Dictionary

corpus_texts_dt[corpus_texts_ls[0]].head()
# Out:
#                                             text_raw  \
# 0  The North Carolina Mutual Life Insurance agent...
# 1  Two days before the event was to take place he...
# 2  At 3:00 p.m. on Wednesday the 18th of February...
# 3                                 Please forgive me.
# 4                                   I loved you all.
#
#                                           text_clean
# 0  the north carolina mutual life insurance agent...
# 1  two day before the event be to take place he t...
# 2  at p be on wednesday the 18th of february i wi...
# 3                                  please forgive me
# 4                                     i love you all

# %% [markdown]
# # **[STEP 4] Get Sentiments with SyuzhetR (4 Models)**

# %% [markdown]
# ## Compute New SyuzhetR Values

# %%
corpus_texts_ls
# Out:
# ['tmorrison_songofsolomon', 'cliu_threebodyproblem', 'sking_doctorsleep']

# %%
for i, acorpus in enumerate(corpus_texts_ls):
  corpus_texts_dt[acorpus].head()
# Out:
#                                             text_raw  \
# 0  The North Carolina Mutual Life Insurance agent...
# 1  Two days before the event was to take place he...
# 2  At 3:00 p.m. on Wednesday the 18th of February...
# 3                                 Please forgive me.
# 4                                   I loved you all.
#
#                                           text_clean
# 0  the north carolina mutual life insurance agent...
# 1  two day before the event be to take place he t...
# 2  at p be on wednesday the 18th of february i wi...
# 3                                  please forgive me
# 4                                     i love you all
#                                             text_raw  \
# 0                                      SILENT SPRING
# 1                                  The Madness Years
# 2                                        China, 1967
# 3  The Red Union had been attacking the headquart...
# 4  Their red flags fluttered restlessly around th...
#
#                                           text_clean
# 0                                      silent spring
# 1                                   the madness year
# 2                                              china
# 3  the red union have be attack the headquarter o...
# 4  their red flag flutter restlessly around the b...
#                                             text_raw  \
# 0  When I was playing my primitive brand of rhyth...
# 1  Warren loved gray t-shirts and movies like Kin...
# 2  He insisted I sing lead on his signature tune,...
# 3                           I said I was not worthy.
# 4                            He insisted that I was.
#
#                                           text_clean
# 0  when i be play my primitive brand of rhythm gu...
# 1  warren love gray t shirt and movie like kingdo...
# 2  he insist i sing lead on his signature tune we...
# 3                              i say i be not worthy
# 4                                he insist that i be

# %%
# Verify text_clean of sample text

corpus_texts_dt[corpus_texts_ls[0]]['text_clean'].to_list()[:10]
# Out:
# ['the north carolina mutual life insurance agent promise to fly from mercy to the other side of lake superior at three of the clock',
#  'two day before the event be to take place he tack a note on the door of his little yellow house',
#  'at p be on wednesday the 18th of february i will take off from mercy and fly away on my own wing',
#  'please forgive me',
#  'i love you all',
#  'sign robert smith',
#  'ins',
#  'agent',
#  'mr smith do not draw a big a crowd a lindbergh have four year earliernot much than forty or fifty people show upbecause it be already eleven of the clock in the morning on the very wednesday he have choose for his flight before anybody read the note',
#  'at that time of day during the middle of the week word of mouth news just lumber along']

# %%
# %%time

# Compute Sentiments from all 4 Syuzhet Models applied to all 32 Novels (4 x 32 = 128 runs)

# NOTE:  9m45s 23:30 on 20220114 Colab Pro (33 Novels)
#       28:32s 21:06 on 20220226 Colab Pro (33 Novels)
#        3m20s 19:11 on 20220217 Colab Pro (2 Novels)
#        3m05s 19:17 on 20220217 Colab Pro (2 Novels)

#        2m21s 00:57 @20220406Wed Colab Pro (2 Novels)

#        1h29m 09:24 @20220406Wed Colab Pro (2 Financial Ref: Speeches FedGov & EU CenBank)

#        3m05s 21:13 on 20220415 Colab Pro (3 Novels, 628k, 662k, 897k)
#        3m05s 21:48 on 20220415 Colab Pro (3 Novels, 628k, 662k, 897k)
#        6m03s 07:39 on 20220416 Colab Pro (3 Novels, 628k, 662k, 897k)

# base = importr('base')
syuzhet = importr('syuzhet')

# corpus_syuzhetr_dt = {}

# base.rank(0, na_last = True)
texts_titles_ls = list(corpus_texts_dt.keys())
texts_titles_ls.sort()
for i, anovel in enumerate(texts_titles_ls):
  print(f'Processing Novel #{i}: {anovel}...')
  corpus_texts_dt[anovel]['syuzhetr_syuzhet'] = syuzhet.get_sentiment(corpus_texts_dt[anovel]['text_clean'].to_list(), method='syuzhet')
  corpus_texts_dt[anovel]['syuzhetr_bing'] = syuzhet.get_sentiment(corpus_texts_dt[anovel]['text_clean'].to_list(), method='bing')
  corpus_texts_dt[anovel]['syuzhetr_afinn'] = syuzhet.get_sentiment(corpus_texts_dt[anovel]['text_clean'].to_list(), method='afinn')
  corpus_texts_dt[anovel]['syuzhetr_nrc'] = syuzhet.get_sentiment(corpus_texts_dt[anovel]['text_clean'].to_list(), method='nrc')
# Out:
# Processing Novel #0: cliu_threebodyproblem...
# Processing Novel #1: sking_doctorsleep...
# Processing Novel #2: tmorrison_songofsolomon...
# CPU times: user 5min 50s, sys: 1.65 s, total: 5min 51s
# Wall time: 6min 3s

# %%
# %whos list
# Out:
# Variable           Type    Data/Info
# ------------------------------------
# corpus_texts_ls    list    n=3
# corpus_titles_ls   list    n=3
# preprocessed_ls    list    n=3
# texts_titles_ls    list    n=3

# %%
texts_titles_ls
# Out:
# ['cliu_threebodyproblem', 'sking_doctorsleep', 'tmorrison_songofsolomon']

# %%
corpus_texts_dt[texts_titles_ls[0]].head()
# Out:
#                                             text_raw  \
# 0                                      SILENT SPRING
# 1                                  The Madness Years
# 2                                        China, 1967
# 3  The Red Union had been attacking the headquart...
# 4  Their red flags fluttered restlessly around th...
#
#                                           text_clean  syuzhetr_syuzhet  \
# 0                                      silent spring              0.00
# 1                                   the madness year             -1.00
# 2                                              china              0.00
# 3  the red union have be attack the headquarter o...             -1.00
# 4  their red flag flutter restlessly around the b...              0.95
#
#    syuzhetr_bing  syuzhetr_afinn  syuzhetr_nrc
# 0              1               0           0.0
# 1             -1              -3          -1.0
# 2              0               0           0.0
# 3             -1              -1          -2.0
# 4              2               2           0.0

# %%
# Verify First Text in Corpus has New SyuzhetR Columns with Plausible Values

# corpus_texts_dt[next(iter(corpus_texts_dt))].head()

corpus_texts_dt[texts_titles_ls[0]].head()
corpus_texts_dt[texts_titles_ls[0]].info()

corpus_texts_dt[texts_titles_ls[1]].head()
corpus_texts_dt[texts_titles_ls[1]].info()
# Out:
#                                             text_raw  \
# 0                                      SILENT SPRING
# 1                                  The Madness Years
# 2                                        China, 1967
# 3  The Red Union had been attacking the headquart...
# 4  Their red flags fluttered restlessly around th...
#
#                                           text_clean  syuzhetr_syuzhet  \
# 0                                      silent spring              0.00
# 1                                   the madness year             -1.00
# 2                                              china              0.00
# 3  the red union have be attack the headquarter o...             -1.00
# 4  their red flag flutter restlessly around the b...              0.95
#
#    syuzhetr_bing  syuzhetr_afinn  syuzhetr_nrc
# 0              1               0           0.0
# 1             -1              -3          -1.0
# 2              0               0           0.0
# 3             -1              -1          -2.0
# 4              2               2           0.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9081 entries, 0 to 9080
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   text_raw          9081 non-null   object
#  1   text_clean        9081 non-null   object
#  2   syuzhetr_syuzhet  9081 non-null   float64
#  3   syuzhetr_bing     9081 non-null   int64
#  4   syuzhetr_afinn    9081 non-null   int64
#  5   syuzhetr_nrc      9081 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 496.6+ KB
#                                             text_raw  \
# 0  When I was playing my primitive brand of rhyth...
# 1  Warren loved gray t-shirts and movies like Kin...
# 2  He insisted I sing lead on his signature tune,...
# 3                           I said I was not worthy.
# 4                            He insisted that I was.
#
#                                           text_clean  syuzhetr_syuzhet  \
# 0  when i be play my primitive brand of rhythm gu...             -0.60
# 1  warren love gray t shirt and movie like kingdo...              1.25
# 2  he insist i sing lead on his signature tune we...              1.20
# 3                              i say i be not worthy              0.75
# 4                                he insist that i be             -0.25
#
#    syuzhetr_bing  syuzhetr_afinn  syuzhetr_nrc
# 0             -1               0           1.0
# 1              2               4           1.0
# 2              1               0           3.0
# 3              1               2           1.0
# 4              0               0           0.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15754 entries, 0 to 15753
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   text_raw          15754 non-null  object
#  1   text_clean        15754 non-null  object
#  2   syuzhetr_syuzhet  15754 non-null  float64
#  3   syuzhetr_bing     15754 non-null  int64
#  4   syuzhetr_afinn    15754 non-null  int64
#  5   syuzhetr_nrc      15754 non-null  float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 861.5+ KB

# %% [markdown]
# ## Checkpoint: Save SyuzhetR Values

# %%
# %whos str

# %%
# Verify in SentimentArcs Root Directory
#   and destination Subdir for Raw Sentiment Values

# !pwd
print('\n')

print(f'PATH_SENTIMENT_RAW: {PATH_SENTIMENT_RAW}\n\n')

print('Existing Sentiment Datafiles in Destination Subdir:\n')

# !ls $PATH_SENTIMENT_RAW
# Out:
# /gdrive/MyDrive/sentimentarcs_notebooks
#
#
# PATH_SENTIMENT_RAW: ./sentiment_raw/sentiment_raw_novels_new_corpus2/
#
#
# Existing Sentiment Datafiles in Destination Subdir:
#
# sentiment_raw_novels_new_corpus2_transformer_distilrobertafinnews.json
# sentiment_raw_novels_new_corpus2_transformer_finbert.json
# sentiment_raw_novels_new_corpus2_transformer_finberttone.json
# sentiment_raw_novels_new_corpus2_transformer_hinglish.json
# sentiment_raw_novels_new_corpus2_transformer_huggingface.json
# sentiment_raw_novels_new_corpus2_transformer_imdb2way.json
# sentiment_raw_novels_new_corpus2_transformer_nlptown.json
# sentiment_raw_novels_new_corpus2_transformer_roberta15lg.json
# sentiment_raw_novels_new_corpus2_transformer_roberta.json
# sentiment_raw_novels_new_corpus2_transformer_robertaxml8lang.json
# sentiment_raw_novels_new_corpus2_transformer_t5base50k.json
# sentiment_raw_novels_new_corpus2_transformer_yelp.json

# %%
# Verify Saving Corpus

print(f'Saving Text_Type: {Corpus_Genre}')
print(f'     Corpus_Type: {Corpus_Type}')

print(f'\nThese Text Titles:\n')
corpus_texts_dt.keys()

print(f'\nTo This Subdirectory:\n')
PATH_SENTIMENT_RAW
# Out:
# Saving Text_Type: novels
#      Corpus_Type: new
#
# These Text Titles:
# dict_keys(['cliu_threebodyproblem', 'sking_doctorsleep', 'tmorrison_songofsolomon'])
# To This Subdirectory:
# './sentiment_raw/sentiment_raw_novels_new_corpus2/'

# %%
# Reorder and filter out cols/models to save

syuzhetr_only_dt = {}
cols_syuzhetr_ls = []

for i, atext in enumerate(corpus_texts_ls):
  print(f'\n\nText #{i}: {atext}')
  # print(f'      {corpus_texts_dt[atext].info()}')
  cols_syuzhetr_ls = [x for x in corpus_texts_dt[atext].columns if 'syuzhetr' in x]
  cols_syuzhetr_ls = ['text_raw', 'text_clean'] + cols_syuzhetr_ls
  # print(f'      {cols_syuzhetr_ls}')
  syuzhetr_only_dt[atext] = corpus_texts_dt[atext][cols_syuzhetr_ls]
  syuzhetr_only_dt[atext].columns
# Out:
# Text #0: tmorrison_songofsolomon
# Index(['text_raw', 'text_clean', 'syuzhetr_syuzhet', 'syuzhetr_bing',
#        'syuzhetr_afinn', 'syuzhetr_nrc'],
#       dtype='object')
# Text #1: cliu_threebodyproblem
# Index(['text_raw', 'text_clean', 'syuzhetr_syuzhet', 'syuzhetr_bing',
#        'syuzhetr_afinn', 'syuzhetr_nrc'],
#       dtype='object')
# Text #2: sking_doctorsleep
# Index(['text_raw', 'text_clean', 'syuzhetr_syuzhet', 'syuzhetr_bing',
#        'syuzhetr_afinn', 'syuzhetr_nrc'],
#       dtype='object')

# %%
Corpus_Type
# Out:
# 'new'

# %%
# Save sentiment values to subdir_sentiments

if Corpus_Type == 'new':
  save_filename = f'sentiment_raw_{Corpus_Genre}_{Corpus_Type}_corpus{Corpus_Number}_all_4syuzhetr.json'
elif Corpus_Type == 'reference':
  save_filename = f'sentiment_raw_{Corpus_Genre}_{Corpus_Type}_all_4syuzhetr.json'
else:
  print(f'ERROR: Illegal Corpus_Type: {Corpus_Type}')

write_dict_dfs(syuzhetr_only_dt, out_file=save_filename, out_dir=f'{PATH_SENTIMENT_RAW}')
# Out:
# Saving file to: ./sentiment_raw/sentiment_raw_novels_new_corpus2/sentiment_raw_novels_new_corpus2_all_4syuzhetr.json

# %%
# Verify json file created

# !ls -altr $PATH_SENTIMENT_RAW
# Out:
# total 147315
# -rw------- 1 root root 10018151 Apr 12 15:50 sentiment_raw_novels_new_corpus2_transformer_huggingface.json
# -rw------- 1 root root  9989234 Apr 12 16:42 sentiment_raw_novels_new_corpus2_transformer_nlptown.json
# -rw------- 1 root root  8483026 Apr 13 03:29 sentiment_raw_novels_new_corpus2_transformer_roberta.json
# -rw------- 1 root root  7619669 Apr 13 04:04 sentiment_raw_novels_new_corpus2_transformer_yelp.json
# -rw------- 1 root root  8573903 Apr 13 04:38 sentiment_raw_novels_new_corpus2_transformer_hinglish.json
# -rw------- 1 root root  9528137 Apr 13 04:55 sentiment_raw_novels_new_corpus2_transformer_imdb2way.json
# -rw------- 1 root root 10537752 Apr 13 05:13 sentiment_raw_novels_new_corpus2_transformer_t5base50k.json
# -rw------- 1 root root 12062880 Apr 13 05:44 sentiment_raw_novels_new_corpus2_transformer_robertaxml8lang.json
# -rw------- 1 root root 13239203 Apr 13 06:15 sentiment_raw_novels_new_corpus2_transformer_finberttone.json
# -rw------- 1 root root  8482983 Apr 13 09:11 sentiment_raw_novels_new_corpus2_transformer_roberta15lg.json
# -rw------- 1 root root  8180667 Apr 13 12:42 sentiment_raw_novels_new_corpus2_transformer_distilrobertafinnews.json
# -rw------- 1 root root  9198194 Apr 13 13:12 sentiment_raw_novels_new_corpus2_transformer_finbert.json
# -rw------- 1 root root 11644364 Apr 16 11:48 sentiment_raw_novels_new2_4syuzhetr.json
# -rw------- 1 root root 11644364 Apr 16 11:49 sentiment_raw_novels_new_corpus2_4syuzhetr.json
# -rw------- 1 root root 11644364 Apr 16 11:50 sentiment_raw_novels_new_corpus2_all_4syuzhetr.json

# %%
corpus_texts_dt[corpus_texts_ls[0]].head()
# Out:
#                                             text_raw  \
# 0  The North Carolina Mutual Life Insurance agent...
# 1  Two days before the event was to take place he...
# 2  At 3:00 p.m. on Wednesday the 18th of February...
# 3                                 Please forgive me.
# 4                                   I loved you all.
#
#                                           text_clean  syuzhetr_syuzhet  \
# 0  the north carolina mutual life insurance agent...              3.10
# 1  two day before the event be to take place he t...              0.00
# 2  at p be on wednesday the 18th of february i wi...              1.00
# 3                                  please forgive me              1.50
# 4                                     i love you all              0.75
#
#    syuzhetr_bing  syuzhetr_afinn  syuzhetr_nrc
# 0              3               5           4.0
# 1              0               0           0.0
# 2              1               2           1.0
# 3              0               2           1.0
# 4              1               3           1.0

# %%
# Verify Dictionary was saved correctly by reading back the *.json datafile

test_dt = read_dict_dfs(in_file=save_filename, in_dir=f'{PATH_SENTIMENT_RAW}/')
test_dt.keys()
# Out:
# dict_keys(['cliu_threebodyproblem', 'sking_doctorsleep', 'tmorrison_songofsolomon'])

# %% [markdown]
# ## Plot SyuzhetR 4 Models

# %%
#@markdown Select option to save plots:
Save_Raw_Plots = True #@param {type:"boolean"}

Save_Smooth_Plots = True #@param {type:"boolean"}
Resolution_in_dpi = "300" #@param ["100", "300"]

# %%
# Get Col Names for all 4 SyuzhetR Models

cols_all_ls = corpus_texts_dt[texts_titles_ls[0]].columns

cols_syuzhetr_ls = [x for x in cols_all_ls if 'syuzhetr_' in x]
cols_syuzhetr_ls
# Out:
# ['syuzhetr_syuzhet', 'syuzhetr_bing', 'syuzhetr_afinn', 'syuzhetr_nrc']

# %%
corpus_texts_dt[next(iter(corpus_texts_dt))].iloc[0]
# Out:
# text_raw            SILENT SPRING
# text_clean          silent spring
# syuzhetr_syuzhet              0.0
# syuzhetr_bing                   1
# syuzhetr_afinn                  0
# syuzhetr_nrc                  0.0
# Name: 0, dtype: object

# %%
print(f'Saving Plots to Subdir: {global_vars.SUBDIR_GRAPHS}')
# Out:
# Saving Plots to Subdir: ./graphs/graphs_novels/

# %%
global_vars.SUBDIR_GRAPHS
# Out:
# './graphs/graphs_novels/'

# %%
global_vars.SUBDIR_GRAPHS = 'graphs/'
global_vars.SUBDIR_GRAPHS
# Out:
# 'graphs/'

# %%
corpus_texts_dt.keys()
# Out:
# dict_keys(['cliu_threebodyproblem', 'sking_doctorsleep', 'tmorrison_songofsolomon'])

# %%
global_vars.corpus_titles_dt.keys()
# Out:
# dict_keys(['tmorrison_songofsolomon', 'cliu_threebodyproblem', 'sking_doctorsleep'])

# %%
global_vars.SUBDIR_TEXT_RAW

# %%
# Save sentiment values to subdir_sentiments

if Corpus_Type == 'new':
  SUBDIR_GRAPH = f'graphs_{Corpus_Genre}_{Corpus_Type}_corpus{Corpus_Number}/'
  # save_filename = f'sentiment_raw_{Corpus_Genre}_{Corpus_Type}_corpus{Corpus_Number}_all_4syuzhetr.json'
elif Corpus_Type == 'reference':
  SUBDIR_GRAPH = f'graphs_{Corpus_Genre}_{Corpus_Type}/'
  # save_filename = f'sentiment_raw_{Corpus_Genre}_{Corpus_Type}_all_4syuzhetr.json'
else:
  print(f'ERROR: Illegal Corpus_Type: {Corpus_Type}')

print(f'SUBDIR_GRAPH: {global_vars.SUBDIR_GRAPHS}{SUBDIR_GRAPH}')
# print(f'save_filename: {save_filename}')
# write_dict_dfs(syuzhetr_only_dt, out_file=save_filename, out_dir=f'{PATH_SENTIMENT_RAW}')
# Out:
# SUBDIR_GRAPH: graphs/graphs_novels_new_corpus2/

# %%
# Verify 4 SyuzhetR Models with Plots

for i, anovel in enumerate(list(corpus_texts_dt.keys())):

  print(f'Novel #{i}: {global_vars.corpus_titles_dt[anovel][0]}')

  # Raw Sentiments 
  fig = corpus_texts_dt[anovel][cols_syuzhetr_ls].plot(title=f'{global_vars.corpus_titles_dt[anovel][0]}\n SyuzhetR 4 Models: Raw Sentiments', alpha=0.3)
  # plt.show();

  if Save_Raw_Plots:
    # save_filename = f'{global_vars.SUBDIR_GRAPHS}plot_{anovel}_syuzhetr_raw_dpi{Resolution_in_dpi}.png'
    save_filename = f'{Path_to_SentimentArcs}{SUBDIR_GRAPH}plot_{anovel}_syuzhetr_raw_dpi{Resolution_in_dpi}.png'
    print(f'\n\nSaving to: {save_filename}')
    plt.savefig(save_filename, dpi=int(Resolution_in_dpi))

  
  # Smoothed Sentiments (SMA 10%)
  # novel_sample = 'cdickens_achristmascarol'
  win_10per = int(corpus_texts_dt[anovel].shape[0] * 0.1)
  corpus_texts_dt[anovel][cols_syuzhetr_ls].rolling(win_10per, center=True, min_periods=0).mean().plot(title=f'{global_vars.corpus_titles_dt[anovel][0]}\n SyuzhetR 4 Models: Smoothed Sentiments (SMA 10%)', alpha=0.3)
  # plt.show();

  if Save_Smooth_Plots:
    # save_filename = f'{global_vars.SUBDIR_GRAPHS}plot_{anovel}_syuzhetr_smooth10sma_dpi{Resolution_in_dpi}.png'
    save_filename = f'{Path_to_SentimentArcs}{SUBDIR_GRAPH}plot_{anovel}_syuzhetr_smooth10sma_dpi{Resolution_in_dpi}.png'
    print(f'\n\nSaving to: {save_filename}')
    plt.savefig(save_filename, dpi=int(Resolution_in_dpi))
# Out:
# Novel #0: The Three Body Problem by Cixin Liu
#
#
# Saving to: /gdrive/MyDrive/sentimentarcs_notebooks/graphs/graphs_novels/graphs_novels_new_corpus2/plot_cliu_threebodyproblem_syuzhetr_raw_dpi300.png
# Saving to: /gdrive/MyDrive/sentimentarcs_notebooks/graphs/graphs_novels/graphs_novels_new_corpus2/plot_cliu_threebodyproblem_syuzhetr_smooth10sma_dpi300.png
# Novel #1: Doctor Sleep by Stphen King
#
#
# Saving to: /gdrive/MyDrive/sentimentarcs_notebooks/graphs/graphs_novels/graphs_novels_new_corpus2/plot_sking_doctorsleep_syuzhetr_raw_dpi300.png
# Saving to: /gdrive/MyDrive/sentimentarcs_notebooks/graphs/graphs_novels/graphs_novels_new_corpus2/plot_sking_doctorsleep_syuzhetr_smooth10sma_dpi300.png
# Novel #2: Song of Solomon by Toni Morrison
#
#
# Saving to: /gdrive/MyDrive/sentimentarcs_notebooks/graphs/graphs_novels/graphs_novels_new_corpus2/plot_tmorrison_songofsolomon_syuzhetr_raw_dpi300.png
# Saving to: /gdrive/MyDrive/sentimentarcs_notebooks/graphs/graphs_novels/graphs_novels_new_corpus2/plot_tmorrison_songofsolomon_syuzhetr_smooth10sma_dpi300.png

# %% [markdown]
# # **[STEP 5] Get Sentiments with SentimentR (7 Models)**

# %% [markdown]
# ## Compute New SentimentR Values
#
# Call function in external get_sentimentr.R from within Python Loop
#
# * https://medium.com/analytics-vidhya/calling-r-from-python-magic-of-rpy2-d8cbbf991571
#
# * https://rpy2.github.io/doc/v3.0.x/html/generated_rst/pandas.html

# %%
# %%file get_sentimentr.R
#
# library(sentimentr)
# library(lexicon)
#
# get_sentimentr_values <- function(s_v) {
#
#   print('Processing sentimentr_jockersrinker')
#   sentimentr_jockersrinker <- sentiment(s_v, polarity_dt=lexicon::hash_sentiment_jockers_rinker,
#                                         hypen="", amplifier.weight=0.8, n.before=5, n.after=2,
#                                         adversative.weight=0.25, neutral.nonverb.like = FALSE, missing_value = 0)
#
#   print('Processing sentimentr_jockers')
#   sentimentr_jockers <- sentiment(s_v, polarity_dt=lexicon::hash_sentiment_jockers,
#                                         hypen="", amplifier.weight=0.8, n.before=5, n.after=2,
#                                         adversative.weight=0.25, neutral.nonverb.like = FALSE, missing_value = 0)
#
#   print('Processing sentimentr_huliu')
#   sentimentr_huliu <- sentiment(s_v, polarity_dt=lexicon::hash_sentiment_huliu,
#                                         hypen="", amplifier.weight=0.8, n.before=5, n.after=2,
#                                         adversative.weight=0.25, neutral.nonverb.like = FALSE, missing_value = 0)
#
#   print('Processing sentimentr_nrc')
#   sentimentr_nrc <- sentiment(s_v, polarity_dt=lexicon::hash_sentiment_nrc,
#                                         hypen="", amplifier.weight=0.8, n.before=5, n.after=2,
#                                         adversative.weight=0.25, neutral.nonverb.like = FALSE, missing_value = 0)
#
#   print('Processing sentimentr_senticnet')
#   sentimentr_senticnet <- sentiment(s_v, polarity_dt=lexicon::hash_sentiment_senticnet,
#                                         hypen="", amplifier.weight=0.8, n.before=5, n.after=2,
#                                         adversative.weight=0.25, neutral.nonverb.like = FALSE, missing_value = 0)
#
#   print('Processing sentimentr_sentiword')
#   sentimentr_sentiword <- sentiment(s_v, polarity_dt=lexicon::hash_sentiment_sentiword,
#                                         hypen="", amplifier.weight=0.8, n.before=5, n.after=2,
#                                         adversative.weight=0.25, neutral.nonverb.like = FALSE, missing_value = 0)
#
#   print('Processing sentimentr_loughran_mcdonald')
#   sentimentr_loughran_mcdonald <- sentiment(s_v, polarity_dt=lexicon::hash_sentiment_loughran_mcdonald,
#                                         hypen="", amplifier.weight=0.8, n.before=5, n.after=2,
#                                         adversative.weight=0.25, neutral.nonverb.like = FALSE, missing_value = 0)
#
#   print('Processing sentimentr_socal_google')
#   sentimentr_socal_google <- sentiment(s_v, polarity_dt=lexicon::hash_sentiment_socal_google,
#                                         hypen="", amplifier.weight=0.8, n.before=5, n.after=2,
#                                         adversative.weight=0.25, neutral.nonverb.like = FALSE, missing_value = 0)
#
#   anovel_sentimentr_df <- data.frame('text_clean' = s_v,
#                                 'sentimentr_jockersrinker' = sentimentr_jockersrinker$sentiment,
#                                 'sentimentr_jockers' = sentimentr_jockers$sentiment,
#                                 'sentimentr_huliu' = sentimentr_huliu$sentiment,
#                                 'sentimentr_nrc' = sentimentr_nrc$sentiment,
#                                 'sentimentr_senticnet' = sentimentr_senticnet$sentiment,
#                                 'sentimentr_sentiword' = sentimentr_sentiword$sentiment,
#                                 'sentimentr_loughran_mcdonald' = sentimentr_loughran_mcdonald$sentiment,
#                                 'sentimentr_socal_google' = sentimentr_socal_google$sentiment
#                                 )
#   return(anovel_sentimentr_df)
#
# }
# Out:
# Overwriting get_sentimentr.R

# %%
# Verify the *.R file above was written correctly

# !cat get_sentimentr.R
# Out:
# library(sentimentr)
# library(lexicon)
#
# get_sentimentr_values <- function(s_v) {
#
#   print('Processing sentimentr_jockersrinker')
#   sentimentr_jockersrinker <- sentiment(s_v, polarity_dt=lexicon::hash_sentiment_jockers_rinker,
#                                         hypen="", amplifier.weight=0.8, n.before=5, n.after=2,
#                                         adversative.weight=0.25, neutral.nonverb.like = FALSE, missing_value = 0)
#
#   print('Processing sentimentr_jockers')
#   sentimentr_jockers <- sentiment(s_v, polarity_dt=lexicon::hash_sentiment_jockers,
#                                         hypen="", amplifier.weight=0.8, n.before=5, n.after=2,
#                                         adversative.weight=0.25, neutral.nonverb.like = FALSE, missing_value = 0)
#
#   print('Processing sentimentr_huliu')
#   sentimentr_huliu <- sentiment(s_v, polarity_dt=lexicon::hash_sentiment_huliu,
#                                         hypen="", amplifier.weight=0.8, n.before=5, n.after=2,
#                                         adversative.weight=0.25, neutral.nonverb.like = FALSE, missing_value = 0)
#
#   print('Processing sentimentr_nrc')
#   sentimentr_nrc <- sentiment(s_v, polarity_dt=lexicon::hash_sentiment_nrc,
#                                         hypen="", amplifier.weight=0.8, n.before=5, n.after=2,
#                                         adversative.weight=0.25, neutral.nonverb.like = FALSE, missing_value = 0)
#
#   print('Processing sentimentr_senticnet')
#   sentimentr_senticnet <- sentiment(s_v, polarity_dt=lexicon::hash_sentiment_senticnet,
#                                         hypen="", amplifier.weight=0.8, n.before=5, n.after=2,
#                                         adversative.weight=0.25, neutral.nonverb.like = FALSE, missing_value = 0)
#
#   print('Processing sentimentr_sentiword')
#   sentimentr_sentiword <- sentiment(s_v, polarity_dt=lexicon::hash_sentiment_sentiword,
#                                         hypen="", amplifier.weight=0.8, n.before=5, n.after=2,
#                                         adversative.weight=0.25, neutral.nonverb.like = FALSE, missing_value = 0)
#
#   print('Processing sentimentr_loughran_mcdonald')
#   sentimentr_loughran_mcdonald <- sentiment(s_v, polarity_dt=lexicon::hash_sentiment_loughran_mcdonald,
#                                         hypen="", amplifier.weight=0.8, n.before=5, n.after=2,
#                                         adversative.weight=0.25, neutral.nonverb.like = FALSE, missing_value = 0)
#
#   print('Processing sentimentr_socal_google')
#   sentimentr_socal_google <- sentiment(s_v, polarity_dt=lexicon::hash_sentiment_socal_google,
#                                         hypen="", amplifier.weight=0.8, n.before=5, n.after=2,
#                                         adversative.weight=0.25, neutral.nonverb.like = FALSE, missing_value = 0)
#
#   anovel_sentimentr_df <- data.frame('text_clean' = s_v,
#                                 'sentimentr_jockersrinker' = sentimentr_jockersrinker$sentiment,
#                                 'sentimentr_jockers' = sentimentr_jockers$sentiment,
#                                 'sentimentr_huliu' = sentimentr_huliu$sentiment,
#                                 'sentimentr_nrc' = sentimentr_nrc$sentiment,
#                                 'sentimentr_senticnet' = sentimentr_senticnet$sentiment,
#                                 'sentimentr_sentiword' = sentimentr_sentiword$sentiment,
#                                 'sentimentr_loughran_mcdonald' = sentimentr_loughran_mcdonald$sentiment,
#                                 'sentimentr_socal_google' = sentimentr_socal_google$sentiment
#                                 )
#   return(anovel_sentimentr_df)
#
# }

# %%
# Setup python robject with external library::function()
# https://rpy2.github.io/doc/v3.0.x/html/generated_rst/pandas.html

# import rpy2.robjects as robjects

# Defining the R script and loading the instance in Python
# from rpy2.robjects import pandas2ri 
r = robjects.r

# Loading the function we have defined in R.
r['source']('get_sentimentr.R')

# Reading and processing data
get_sentimentr_function_r = robjects.globalenv['get_sentimentr_values']
# Out:
# <rpy2.robjects.vectors.ListVector object at 0x7f55f08bc370> [RTYPES.VECSXP]
# R classes: ('list',)
# [SexpClosure, BoolSexpVector]
#   value: <class 'rpy2.rinterface.SexpClosure'>
#   <rpy2.rinterface.SexpClosure object at 0x7f55f08bc410> [RTYPES.CLOSXP]
#   visible: <class 'rpy2.rinterface.BoolSexpVector'>
#   <rpy2.rinterface.BoolSexpVector object at 0x7f55f08bc2d0> [RTYPES.LGLSXP]

# %%
corpus_texts_dt.keys()
# Out:
# dict_keys(['cliu_threebodyproblem', 'sking_doctorsleep', 'tmorrison_songofsolomon'])

# %%
# Test

# Convert Python List of Strings to a R vector of characters
# test_ls = corpus_texts_dt[next(iter(corpus_texts_dt))]['text_clean'].to_list()
test_ls = corpus_texts_dt[corpus_texts_ls[0]]['text_clean'].to_list()
s_v = robjects.StrVector(test_ls)
type(s_v)

get_sentimentr_function_r(s_v)
# Out:
# rpy2.robjects.vectors.StrVector
# [1] "Processing sentimentr_jockersrinker"
# [1] "Processing sentimentr_jockers"
# [1] "Processing sentimentr_huliu"
# [1] "Processing sentimentr_nrc"
# [1] "Processing sentimentr_senticnet"
# [1] "Processing sentimentr_sentiword"
# [1] "Processing sentimentr_loughran_mcdonald"
# [1] "Processing sentimentr_socal_google"
# <rpy2.robjects.vectors.DataFrame object at 0x7f55f18d76e0> [RTYPES.VECSXP]
# R classes: ('data.frame',)
# [StrSexpVe..., FloatSexp..., FloatSexp..., FloatSexp..., ..., FloatSexp..., FloatSexp..., FloatSexp..., FloatSexp...]
#   text_clean: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#   <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f55f104fdc0> [RTYPES.STRSXP]
#   sentimentr_jockersrinker: <class 'rpy2.rinterface.FloatSexpVector'>
#   <rpy2.rinterface.FloatSexpVector object at 0x7f55f107e4b0> [RTYPES.REALSXP]
#   sentimentr_jockers: <class 'rpy2.rinterface.FloatSexpVector'>
#   <rpy2.rinterface.FloatSexpVector object at 0x7f55f107e550> [RTYPES.REALSXP]
#   sentimentr_huliu: <class 'rpy2.rinterface.FloatSexpVector'>
#   <rpy2.rinterface.FloatSexpVector object at 0x7f55f107e3c0> [RTYPES.REALSXP]
#   sentimentr_nrc: <class 'rpy2.rinterface.FloatSexpVector'>
#   <rpy2.rinterface.FloatSexpVector object at 0x7f55f107e550> [RTYPES.REALSXP]
#   sentimentr_senticnet: <class 'rpy2.rinterface.FloatSexpVector'>
#   <rpy2.rinterface.FloatSexpVector object at 0x7f55f107e3c0> [RTYPES.REALSXP]
#   sentimentr_sentiword: <class 'rpy2.rinterface.FloatSexpVector'>
#   <rpy2.rinterface.FloatSexpVector object at 0x7f561de7c050> [RTYPES.REALSXP]
#   sentimentr_loughran_mcdonald: <class 'rpy2.rinterface.FloatSexpVector'>
#   <rpy2.rinterface.FloatSexpVector object at 0x7f561de7c410> [RTYPES.REALSXP]
#   sentimentr_socal_google: <class 'rpy2.rinterface.FloatSexpVector'>
#   <rpy2.rinterface.FloatSexpVector object at 0x7f561de7c050> [RTYPES.REALSXP]

# %%
corpus_texts_dt.keys()
# Out:
# dict_keys(['cliu_threebodyproblem', 'sking_doctorsleep', 'tmorrison_songofsolomon'])

# %%
text_clean_ct = corpus_texts_dt[next(iter(corpus_texts_dt))].text_clean.isna().sum()
text_clean_ct
# len(text_clean_ls.isnull())
# Out:
# 0

# %% [markdown]
# **[RE-EXECUTE] May have to re-execute following code cell several times**

# %%
# %whos dict
# Out:
# Variable          Type    Data/Info
# -----------------------------------
# corpus_texts_dt   dict    n=3
# test_dt           dict    n=3

# %%
corpus_texts_dt.keys()
# Out:
# dict_keys(['cliu_threebodyproblem', 'sking_doctorsleep', 'tmorrison_songofsolomon'])

# %%
# %%time

# NOTE:  8m19s 13 Novels 
#       16m39s 19 Novels
#      -----------------
#       24m58s 32 Novels
#        5m00s  @19:44 on 20220227 Colab Pro (2 Novels)

#        3m18s 21:24 on 20220415 Colab Pro (3 Novels, 628k, 662k, 897k)
#        3m09s 21:45 on 20220415 Colab Pro (3 Novels, 628k, 662k, 897k)


# Call external get_sentimentr::get_sentimentr_values with Python loop over all novels

# novels_sentimentr_dt = {}

# Reset corpus_texts_dt
# corpus_texts_dt = {}

anovel_df = pd.DataFrame()

novels_titles_ls = list(corpus_texts_dt.keys())
novels_titles_ls.sort()
# for i, anovel in enumerate(novels_titles_ls[:19]):
for i, anovel in enumerate(novels_titles_ls):  
  print(f'\nProcessing Novel #{i}: {anovel}')
  
  # Delete contents of anovel_df DataFrame
  anovel_df = anovel_df[0:0]

  print(f'     {corpus_texts_dt[anovel].shape}')
  # Get text_clean as list of strings
  text_clean_ls = corpus_texts_dt[anovel]['text_clean'].to_list()

  # Convert Python List of Strings to a R vector of characters
  # https://rpy2.github.io/doc/v3.0.x/html/generated_rst/pandas.html
  s_v = robjects.StrVector(text_clean_ls)
  anovel_df_r = get_sentimentr_function_r(s_v)

  # Convert rpy2.robjects.vectors.DataFrame to pandas.core.frame.DataFrame
  # https://stackoverflow.com/questions/20630121/pandas-how-to-convert-r-dataframe-back-to-pandas 
  print(f'type(anovel_df_r): {type(anovel_df_r)}')
  anovel_df = pd.DataFrame.from_dict({ key : np.asarray(anovel_df_r.rx2(key)) for key in anovel_df_r.names })
  print(f'type(anovel_df): {type(anovel_df)}')

  # Save Results
  # novels_dt[anovel] = anovel_df.copy(deep=True)

  # This works for Novels New Corpus Texts
  corpus_texts_dt[anovel]['sentimentr_jockersrinker'] = anovel_df['sentimentr_jockersrinker']
  corpus_texts_dt[anovel]['sentimentr_jockers'] = anovel_df['sentimentr_jockers']
  corpus_texts_dt[anovel]['sentimentr_huliu'] = anovel_df['sentimentr_huliu']
  corpus_texts_dt[anovel]['sentimentr_nrc'] = anovel_df['sentimentr_nrc']
  corpus_texts_dt[anovel]['sentimentr_senticnet'] = anovel_df['sentimentr_senticnet']
  corpus_texts_dt[anovel]['sentimentr_sentiword'] = anovel_df['sentimentr_sentiword']
  corpus_texts_dt[anovel]['sentimentr_loughran_mcdonald'] = anovel_df['sentimentr_loughran_mcdonald']
  corpus_texts_dt[anovel]['sentimentr_socal_google'] = anovel_df['sentimentr_socal_google'] 


"""
  # This works for Novels Reference Corpus Texts
  corpus_texts_dt[anovel]['sentimentr_jockersrinker'] = anovel_df[anovel]['sentimentr_jockersrinker']
  corpus_texts_dt[anovel]['sentimentr_jockers'] = anovel_df[anovel]['sentimentr_jockers']
  corpus_texts_dt[anovel]['sentimentr_huliu'] = anovel_df[anovel]['sentimentr_huliu']
  corpus_texts_dt[anovel]['sentimentr_nrc'] = anovel_df[anovel]['sentimentr_nrc']
  corpus_texts_dt[anovel]['sentimentr_senticnet'] = anovel_df[anovel]['sentimentr_senticnet']
  corpus_texts_dt[anovel]['sentimentr_sentiword'] = anovel_df[anovel]['sentimentr_sentiword']
  corpus_texts_dt[anovel]['sentimentr_loughran_mcdonald'] = anovel_df[anovel]['sentimentr_loughran_mcdonald']
  corpus_texts_dt[anovel]['sentimentr_socal_google'] = anovel_df[anovel]['sentimentr_socal_google'] 
"""
# Out:
# Processing Novel #0: cliu_threebodyproblem
#      (9081, 2)
# [1] "Processing sentimentr_jockersrinker"
# [1] "Processing sentimentr_jockers"
# [1] "Processing sentimentr_huliu"
# [1] "Processing sentimentr_nrc"
# [1] "Processing sentimentr_senticnet"
# [1] "Processing sentimentr_sentiword"
# [1] "Processing sentimentr_loughran_mcdonald"
# [1] "Processing sentimentr_socal_google"
# type(anovel_df_r): <class 'rpy2.robjects.vectors.DataFrame'>
# type(anovel_df): <class 'pandas.core.frame.DataFrame'>
#
# Processing Novel #1: sking_doctorsleep
#      (15754, 2)
# [1] "Processing sentimentr_jockersrinker"
# [1] "Processing sentimentr_jockers"
# [1] "Processing sentimentr_huliu"
# [1] "Processing sentimentr_nrc"
# [1] "Processing sentimentr_senticnet"
# [1] "Processing sentimentr_sentiword"
# [1] "Processing sentimentr_loughran_mcdonald"
# [1] "Processing sentimentr_socal_google"
# type(anovel_df_r): <class 'rpy2.robjects.vectors.DataFrame'>
# type(anovel_df): <class 'pandas.core.frame.DataFrame'>
#
# Processing Novel #2: tmorrison_songofsolomon
#      (10507, 2)
# [1] "Processing sentimentr_jockersrinker"
# [1] "Processing sentimentr_jockers"
# [1] "Processing sentimentr_huliu"
# [1] "Processing sentimentr_nrc"
# [1] "Processing sentimentr_senticnet"
# [1] "Processing sentimentr_sentiword"
# [1] "Processing sentimentr_loughran_mcdonald"
# [1] "Processing sentimentr_socal_google"
# type(anovel_df_r): <class 'rpy2.robjects.vectors.DataFrame'>
# type(anovel_df): <class 'pandas.core.frame.DataFrame'>
# CPU times: user 3min 9s, sys: 467 ms, total: 3min 9s
# Wall time: 3min 9s

# %%
anovel_df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
corpus_texts_dt[texts_titles_ls[0]].head()
# Out:
#                                             text_raw  \
# 0                                      SILENT SPRING
# 1                                  The Madness Years
# 2                                        China, 1967
# 3  The Red Union had been attacking the headquart...
# 4  Their red flags fluttered restlessly around th...
#
#                                           text_clean  \
# 0                                      silent spring
# 1                                   the madness year
# 2                                              china
# 3  the red union have be attack the headquarter o...
# 4  their red flag flutter restlessly around the b...
#
#    sentimentr_jockersrinker  sentimentr_jockers  sentimentr_huliu  \
# 0                  0.707107            0.000000          0.707107
# 1                 -0.577350           -0.577350         -0.577350
# 2                  0.000000            0.000000          0.000000
# 3                 -0.250000           -0.250000         -0.250000
# 4                  0.253898            0.253898          0.534522
#
#    sentimentr_nrc  sentimentr_senticnet  sentimentr_sentiword  \
# 0         0.00000             -0.579828             -0.441942
# 1        -0.57735             -0.330244             -0.108253
# 2         0.00000              0.031000              0.500000
# 3        -0.50000              0.492500             -0.177083
# 4         0.00000              0.195635              0.111359
#
#    sentimentr_loughran_mcdonald  sentimentr_socal_google
# 0                           0.0                -1.322336
# 1                           0.0                 0.000000
# 2                           0.0                 0.000000
# 3                           0.0                 0.175003
# 4                           0.0                 0.187086

# %%
cols_sentimentr_ls = [x for x in corpus_texts_dt[next(iter(corpus_texts_dt))].columns if 'sentimentr_' in x]
cols_sentimentr_ls
# Out:
# ['sentimentr_jockersrinker',
#  'sentimentr_jockers',
#  'sentimentr_huliu',
#  'sentimentr_nrc',
#  'sentimentr_senticnet',
#  'sentimentr_sentiword',
#  'sentimentr_loughran_mcdonald',
#  'sentimentr_socal_google']

# %%
# Verify DataFrame shape of first Text in Corpus

corpus_texts_dt[next(iter(corpus_texts_dt))].shape
# Out:
# (9081, 10)

# %% [markdown]
# ## Checkpoint: Save SentimentR Values

# %%
# Verify in SentimentArcs Root Directory
#   and destination Subdir for Raw Sentiment Values

# !pwd
print('\n')

print(f'PATH_SENTIMENT_RAW: {PATH_SENTIMENT_RAW}\n\n')

print('Existing Sentiment Datafiles in Destination Subdir:\n')

# !ls $PATH_SENTIMENT_RAW
# Out:
# /gdrive/MyDrive/sentimentarcs_notebooks
#
#
# PATH_SENTIMENT_RAW: ./sentiment_raw/sentiment_raw_novels_new_corpus2/
#
#
# Existing Sentiment Datafiles in Destination Subdir:
#
#  all_novels_new_4syuzhetr.json
#  all_novels_new_huggingface.json
# 'Copy of sentiment_raw_novels_new_corpus2_transformer_huggingface.json'
#  sentiment_raw_novels_new_corpus2_transformer_distilrobertafinnews.json
#  sentiment_raw_novels_new_corpus2_transformer_finbert.json
#  sentiment_raw_novels_new_corpus2_transformer_finberttone.json
#  sentiment_raw_novels_new_corpus2_transformer_hinglish.json
#  sentiment_raw_novels_new_corpus2_transformer_huggingface.json
#  sentiment_raw_novels_new_corpus2_transformer_imdb2way.json
#  sentiment_raw_novels_new_corpus2_transformer_nlptown.json
#  sentiment_raw_novels_new_corpus2_transformer_roberta15lg.json
#  sentiment_raw_novels_new_corpus2_transformer_roberta.json
#  sentiment_raw_novels_new_corpus2_transformer_robertaxml8lang.json
#  sentiment_raw_novels_new_corpus2_transformer_t5base50k.json
#  sentiment_raw_novels_new_corpus2_transformer_yelp.json
#  test.txt

# %%
# Verify Saving Corpus

print(f'Saving Text_Type: {Corpus_Genre}')
print(f'     Corpus_Type: {Corpus_Type}')

print(f'\nThese Text Titles:\n')
corpus_texts_dt.keys()
# Out:
# Saving Text_Type: novels
#      Corpus_Type: new
#
# These Text Titles:
# dict_keys(['cliu_threebodyproblem', 'sking_doctorsleep', 'tmorrison_songofsolomon'])

# %%
sentimentr_only_dt = {}
cols_sentimentr_ls = []

for i, atext in enumerate(corpus_texts_ls):
  print(f'\n\nModel #{i}: {amodel}')
  # print(f'      {corpus_texts_dt[amodel].info()}')
  cols_sentimentr_ls = [x for x in corpus_texts_dt[amodel].columns if 'sentimentr' in x]
  cols_sentimentr_ls = ['text_raw', 'text_clean'] + cols_sentimentr_ls
  # print(f'      {cols_syuzhetr_ls}')
  sentimentr_only_dt[atext] = corpus_texts_dt[atext][cols_sentimentr_ls]
  sentimentr_only_dt[atext].columns
# Out:
# Model #0: sking_doctorsleep
# Index(['text_raw', 'text_clean', 'sentimentr_jockersrinker',
#        'sentimentr_jockers', 'sentimentr_huliu', 'sentimentr_nrc',
#        'sentimentr_senticnet', 'sentimentr_sentiword',
#        'sentimentr_loughran_mcdonald', 'sentimentr_socal_google'],
#       dtype='object')
# Model #1: sking_doctorsleep
# Index(['text_raw', 'text_clean', 'sentimentr_jockersrinker',
#        'sentimentr_jockers', 'sentimentr_huliu', 'sentimentr_nrc',
#        'sentimentr_senticnet', 'sentimentr_sentiword',
#        'sentimentr_loughran_mcdonald', 'sentimentr_socal_google'],
#       dtype='object')
# Model #2: sking_doctorsleep
# Index(['text_raw', 'text_clean', 'sentimentr_jockersrinker',
#        'sentimentr_jockers', 'sentimentr_huliu', 'sentimentr_nrc',
#        'sentimentr_senticnet', 'sentimentr_sentiword',
#        'sentimentr_loughran_mcdonald', 'sentimentr_socal_google'],
#       dtype='object')

# %%
# Save sentiment values to subdir_sentiments

save_filename = f'all_{Corpus_Genre}_{Corpus_Type}_8sentimentr.json'

write_dict_dfs(sentimentr_only_dt, out_file=save_filename, out_dir=f'{PATH_SENTIMENT_RAW}')
# Out:
# Saving file to: ./sentiment_raw/sentiment_raw_novels_new_corpus2/all_novels_new_8sentimentr.json

# %%
# Verify Dictionary was saved correctly by reading back the *.json datafile

test_dt = read_dict_dfs(in_file=save_filename, in_dir=f'{PATH_SENTIMENT_RAW}/')
test_dt.keys()
# Out:
# dict_keys(['cliu_threebodyproblem', 'sking_doctorsleep', 'tmorrison_songofsolomon'])

# %% [markdown]
# ## Plot SentimentR 7 Models

# %%
#@markdown Select option to save plots:
Save_Raw_Plots = True #@param {type:"boolean"}

Save_Smooth_Plots = True #@param {type:"boolean"}
Resolution_in_dpi = "300" #@param ["100", "300"]

# %%
# Get Col Names for all SentimentR Models
cols_all_ls = corpus_texts_dt[next(iter(corpus_texts_dt))].columns
cols_sentimentr_ls = [x for x in cols_all_ls if 'sentimentr_' in x]
cols_sentimentr_ls
# Out:
# ['sentimentr_jockersrinker',
#  'sentimentr_jockers',
#  'sentimentr_huliu',
#  'sentimentr_nrc',
#  'sentimentr_senticnet',
#  'sentimentr_sentiword',
#  'sentimentr_loughran_mcdonald',
#  'sentimentr_socal_google']

# %%
corpus_texts_dt[next(iter(corpus_texts_dt))]
# Out:
#                                                text_raw  \
# 0                                         SILENT SPRING
# 1                                     The Madness Years
# 2                                           China, 1967
# 3     The Red Union had been attacking the headquart...
# 4     Their red flags fluttered restlessly around th...
# ...                                                 ...
# 9076  Before everything sank into darkness, she want...
# 9077  Over the western horizon, the sun that was slo...
# 9078  The ruddy sun dissolved into the clouds and sp...
# 9079                           My sunset, Ye whispered.
# 9080                           And sunset for humanity.
#
#                                              text_clean  \
# 0                                         silent spring
# 1                                      the madness year
# 2                                                 china
# 3     the red union have be attack the headquarter o...
# 4     their red flag flutter restlessly around the b...
# ...                                                 ...
# 9076  before everything sink into darkness she want ...
# 9077  over the western horizon the sun that be slowl...
# 9078  the ruddy sun dissolve into the cloud and spre...
# 9079                               my sunset ye whisper
# 9080                            and sunset for humanity
#
#       sentimentr_jockersrinker  sentimentr_jockers  sentimentr_huliu  \
# 0                     0.707107            0.000000          0.707107
# 1                    -0.577350           -0.577350         -0.577350
# 2                     0.000000            0.000000          0.000000
# 3                    -0.250000           -0.250000         -0.250000
# 4                     0.253898            0.253898          0.534522
# ...                        ...                 ...               ...
# 9076                  0.048507            0.048507         -0.485071
# 9077                  0.023570            0.023570         -0.707107
# 9078                  0.134164            0.134164          0.000000
# 9079                  0.300000            0.300000          0.000000
# 9080                  0.425000            0.425000          0.000000
#
#       sentimentr_nrc  sentimentr_senticnet  sentimentr_sentiword  \
# 0           0.000000             -0.579828             -0.441942
# 1          -0.577350             -0.330244             -0.108253
# 2           0.000000              0.031000              0.500000
# 3          -0.500000              0.492500             -0.177083
# 4           0.000000              0.195635              0.111359
# ...              ...                   ...                   ...
# 9076        0.242536              0.266013             -0.069729
# 9077        0.707107             -0.029698             -0.027008
# 9078        0.447214              0.121418             -0.244570
# 9079        0.500000              0.612000             -0.187500
# 9080        1.000000              0.658500              0.000000
#
#       sentimentr_loughran_mcdonald  sentimentr_socal_google
# 0                         0.000000                -1.322336
# 1                         0.000000                 0.000000
# 2                         0.000000                 0.000000
# 3                         0.000000                 0.175003
# 4                         0.000000                 0.187086
# ...                            ...                      ...
# 9076                      0.000000                 0.169778
# 9077                     -0.235702                 0.277823
# 9078                      0.000000                -0.052358
# 9079                      0.000000                 0.000000
# 9080                      0.000000                 0.000000
#
# [9081 rows x 10 columns]

# %%
dir(global_vars)
# Out:
# ['Corpus_Genre',
#  'Corpus_Number',
#  'Corpus_Type',
#  'FNAME_SENTIMENT_RAW',
#  'MIN_PARAG_LEN',
#  'MIN_SENT_LEN',
#  'NotebookModels',
#  'PATH_SENTIMENT_RAW',
#  'PATH_TEXT_CLEAN',
#  'PATH_TEXT_RAW_CORPUS',
#  'SLANG_DT',
#  'STOPWORDS_ADD_EN',
#  'STOPWORDS_DEL_EN',
#  'SUBDIR_CRUXES',
#  'SUBDIR_DATA',
#  'SUBDIR_GRAPHS',
#  'SUBDIR_SENTIMENTARCS',
#  'SUBDIR_SENTIMENT_CLEAN',
#  'SUBDIR_SENTIMENT_RAW',
#  'SUBDIR_TEXT_CLEAN',
#  'SUBDIR_TEXT_RAW',
#  'SUBDIR_TIMESERIES_CLEAN',
#  'SUBDIR_TIMESERIES_RAW',
#  'SUBDIR_UTILS',
#  'TEST_SENTENCES_LS',
#  'TEST_WORDS_LS',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'corpus_texts_dt',
#  'corpus_titles_dt',
#  'corpus_titles_ls',
#  'lexicons_dt',
#  'model_ensemble_dt',
#  'model_titles_dt',
#  'models_ensemble_dt',
#  'models_titles_dt']

# %%
print(f'Saving Plots to SUBDIR_PLOTS: {global_vars.SUBDIR_GRAPHS}')
# Out:
# Saving Plots to SUBDIR_PLOTS: ./graphs/graphs_novels/

# %%
# %whos str
# Out:
# Variable                Type    Data/Info
# -----------------------------------------
# Corpus_Genre            str     novels
# Corpus_Type             str     new
# PATH_SENTIMENT_RAW      str     ./sentiment_raw/sentiment_raw_novels_new_corpus2/
# PATH_TEXT_CLEAN         str     ./text_clean/text_clean_novels_new_corpus2/
# PATH_UTILS              str     /gdrive/MyDrive/sentimentarcs_notebooks/utils
# Path_to_SentimentArcs   str     /gdrive/MyDrive/sentimentarcs_notebooks/
# Resolution_in_dpi       str     300
# SUBDIR_SENTIMENT_RAW    str     sentiment_raw_novels_new_corpus2/
# SUBDIR_TEXT_CLEAN       str     text_clean_novels_new_corpus2/
# acorpus                 str     sking_doctorsleep
# afile_fullpath          str     ./text_clean/text_clean_n<...>orrison_songofsolomon.csv
# akey                    str     Doctor Sleep by Stphen King
# anovel                  str     tmorrison_songofsolomon
# atext                   str     tmorrison_songofsolomon
# save_filename           str     all_novels_new_4sentimentr.json

# %%
print(f'{global_vars.SUBDIR_GRAPHS}plot_sentimentr_raw_{anovel}_dpi{Resolution_in_dpi}.png')
# Out:
# ./graphs/graphs_novels/plot_sentimentr_raw_tmorrison_songofsolomon_dpi300.png

# %%
# Verify 7 SentimentR Models with Plots

for i, anovel in enumerate(list(corpus_texts_dt.keys())):

  print(f'Novel #{i}: {global_vars.corpus_titles_dt[anovel][0]}')

  # Raw Sentiments 
  fig = corpus_texts_dt[anovel][cols_sentimentr_ls].plot(title=f'{global_vars.corpus_titles_dt[anovel][0]}\n SentimentR 7 Models: Raw Sentiments', alpha=0.3)
  # plt.show();

  if Save_Raw_Plots:
    save_filename = f'{global_vars.SUBDIR_GRAPHS}plot_sentimentr_raw_{anovel}_dpi{Resolution_in_dpi}.png'
    save_filename = f'{global_vars.SUBDIR_GRAPHS}plot_sentimentr_raw_{anovel}_dpi{Resolution_in_dpi}.png'
    print(f'\n\nSaving to: {save_filename}')
    plt.savefig(save_filename, dpi=int(Resolution_in_dpi))

  
  # Smoothed Sentiments (SMA 10%)
  # novel_sample = 'cdickens_achristmascarol'
  win_10per = int(corpus_texts_dt[anovel].shape[0] * 0.1)
  corpus_texts_dt[anovel][cols_sentimentr_ls].rolling(win_10per, center=True, min_periods=0).mean().plot(title=f'{global_vars.corpus_titles_dt[anovel][0]}\n SentimentR 7 Models: Smoothed Sentiments (SMA 10%)', alpha=0.3)
  # plt.show();

  if Save_Smooth_Plots:
    save_filename = f'{global_vars.SUBDIR_GRAPHS}plot_sentimentr_smooth10sma_{anovel}_dpi{Resolution_in_dpi}.png'
    print(f'\n\nSaving to: {save_filename}')
    plt.savefig(save_filename, dpi=int(Resolution_in_dpi))
# Out:
# Novel #0: The Three Body Problem by Cixin Liu
#
#
# Saving to: /gdrive/MyDrive/sentimentarcs_notebooks/graphs/graphs_novels/graphs_novels_new_corpus2/plot_cliu_threebodyproblem_sentimentr_raw_dpi300.png
# Saving to: /gdrive/MyDrive/sentimentarcs_notebooks/graphs/graphs_novels/graphs_novels_new_corpus2/plot_cliu_threebodyproblem_sentimentr_raw_dpi300.png
# Novel #1: Doctor Sleep by Stphen King
#
#
# Saving to: /gdrive/MyDrive/sentimentarcs_notebooks/graphs/graphs_novels/graphs_novels_new_corpus2/plot_sking_doctorsleep_sentimentr_raw_dpi300.png
# Saving to: /gdrive/MyDrive/sentimentarcs_notebooks/graphs/graphs_novels/graphs_novels_new_corpus2/plot_sking_doctorsleep_sentimentr_raw_dpi300.png
# Novel #2: Song of Solomon by Toni Morrison
#
#
# Saving to: /gdrive/MyDrive/sentimentarcs_notebooks/graphs/graphs_novels/graphs_novels_new_corpus2/plot_tmorrison_songofsolomon_sentimentr_raw_dpi300.png
# Saving to: /gdrive/MyDrive/sentimentarcs_notebooks/graphs/graphs_novels/graphs_novels_new_corpus2/plot_tmorrison_songofsolomon_sentimentr_raw_dpi300.png

# %%
# %whos

# %%
corpus_texts_ls
# Out:
# ['tmorrison_songofsolomon', 'cliu_threebodyproblem', 'sking_doctorsleep']

# %%
text_indx = 0

corpus_texts_dt[corpus_texts_ls[text_indx]].head()
# Out:
#                                             text_raw  \
# 0  The North Carolina Mutual Life Insurance agent...
# 1  Two days before the event was to take place he...
# 2  At 3:00 p.m. on Wednesday the 18th of February...
# 3                                 Please forgive me.
# 4                                   I loved you all.
#
#                                           text_clean  \
# 0  the north carolina mutual life insurance agent...
# 1  two day before the event be to take place he t...
# 2  at p be on wednesday the 18th of february i wi...
# 3                                  please forgive me
# 4                                     i love you all
#
#    sentimentr_jockersrinker  sentimentr_jockers  sentimentr_huliu  \
# 0                  0.632785            0.632785          0.612372
# 1                  0.000000            0.000000          0.000000
# 2                  0.213201            0.213201          0.213201
# 3                  0.866025            0.866025          0.000000
# 4                  0.375000            0.375000          0.500000
#
#    sentimentr_nrc  sentimentr_senticnet  sentimentr_sentiword  \
# 0        0.816497              0.903045             -0.008505
# 1        0.000000              0.345613              0.066829
# 2        0.213201             -0.063534             -0.066625
# 3        0.577350              0.525966              0.216506
# 4        0.500000              0.626000              0.437500
#
#    sentimentr_loughran_mcdonald  sentimentr_socal_google
# 0                      0.204124                 0.309791
# 1                      0.000000                -0.017644
# 2                      0.000000                 0.434576
# 3                      0.000000                 0.000000
# 4                      0.000000                 0.000000

# %%
sentence_start = 50
sentence_end = 60

' '.join(list(corpus_texts_dt[corpus_texts_ls[text_indx]].iloc[sentence_start:sentence_end]['text_raw']))
# Out:
# 'The sight of Mr. Smith and his wide blue wings transfixed them for a few seconds, as did the womans singing and the roses strewn about. Some of them thought briefly that this was probably some form of worship. Philadelphia, where Father Divine reigned, wasnt all that far away. Perhaps the young girls holding baskets of flowers were two of his virgins. But the laughter of a gold-toothed man brought them back to their senses. They stopped daydreaming and swiftly got down to business, giving orders. Their shouts and bustling caused great confusion where before there had been only a few men and some girls playing with pieces of velvet and a woman singing. One of the nurses, hoping to bring some efficiency into the disorder, searched the faces around her until she saw a stout woman who looked as though she might move the earth if she wanted to. You, she said, moving toward the stout woman. Are these your children?'

# %% [markdown]
# # **END OF NOTEBOOK**

# %% [markdown]
# ---
