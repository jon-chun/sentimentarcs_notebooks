# %% [markdown]
# # **SentimentArcs (Part 10) Setup**
#
# ```
# Jon Chun
# 12 Jun 2021: Started
# 04 Apr 2022: Last Update
# ```
#
# This notebook should only be run once to initially copy the SentimentArcs Github repo to your Google GDrive.
#
# To copy the latest version of SentimentArcs to your GDrive
#
# 1. Backup the folders (and their contents) holding your raw data and analysis
#
# * ./text_raw
# * ./text_clean
# * ./sentiment_raw
# * ./sentiment_clean
# * ./graphs
#
# 2. Delete or rename the 'sentimentarcs_notebook' folder (e.g. sentimentarcs_notebook_old)
#
#
# 3. Run this notebook to create a new, updated sentimentarcs_notebook folder

# %% [markdown]
# # **[STEP 1] Manual Configuration/Setup**

# %% [markdown]
# ## (Popups) Connect Google gDrive

# %%
# [INPUT REQUIRED]: Authorize access to Google gDrive

# Connect this Notebook to your permanent Google Drive
#   so all generated output is saved to permanent storage there

try:
  from google.colab import drive
  IN_COLAB=True
except:
  IN_COLAB=False

if IN_COLAB:
  print("Attempting to attach your Google gDrive to this Colab Jupyter Notebook")
  drive.mount('/gdrive', force_remount=True)
else:
  print("Your Google gDrive is attached to this Colab Jupyter Notebook")
# Out:
# Attempting to attach your Google gDrive to this Colab Jupyter Notebook
# Mounted at /gdrive

# %% [markdown]
# ## (3 Inputs) Define Directory Tree

# %%
# [CUSTOMIZE]: Change the text after the Unix '%cd ' command below (change directory)
#              to math the full path to your gDrive subdirectory which should be the 
#              root directory cloned from the SentimentArcs github repo.

# NOTE: Make sure this Directory already exists and there are 
#       no typos, spaces or illegal characters (e.g. periods) in the full path after %cd

# NOTE: In Python all strings must begin with an upper or lowercase letter, and only
#         letter, number and underscores ('_') characters should appear afterwards.
#         Make sure your full path after %cd obeys this constraint or errors may appear.

#@markdown **Instructions**

#@markdown <li> Set <b>Parent_Directory_of_SentimentArcs</b> to the Parent Directory where SentimentArcs should be installed on your Google GDrive
#@markdown <li> Make sure your path has no typos, spaces or illegal characters
#@markdown <li> Use only valid Python variable characters: alphanumeric and underscores
#@markdown <li> Begin all path directory names with a letter (no numbers or underscores)
#@markdown <li> Verfiy there is enough free space on your Google GDrive to copy SentimentArcs (code base: 200MB plus about 200MB per novel)

# Step #1: Get full path to SentimentArcs subdir on gDrive
# =======
#@markdown **Accept default path on gDrive or Enter new one:**

Parent_Directory_of_SentimentArcs = "/gdrive/MyDrive/" #@param ["/gdrive/MyDrive/sentiment_arcs/"] {allow-input: true}

print('Current Working Directory:')
# %cd $Parent_Directory_of_SentimentArcs
# Out:
# Current Working Directory:
# /gdrive/MyDrive

# %%
# !git clone https://github.com/jon-chun/sentimentarcs_notebooks.git
# Out:
# Cloning into 'sentimentarcs_notebooks'...
# remote: Enumerating objects: 194, done.
# remote: Counting objects: 100% (194/194), done.
# remote: Compressing objects: 100% (170/170), done.
# remote: Total 194 (delta 27), reused 178 (delta 19), pack-reused 0
# Receiving objects: 100% (194/194), 46.32 MiB | 14.76 MiB/s, done.
# Resolving deltas: 100% (27/27), done.
# Checking out files: 100% (295/295), done.

# %% [markdown]
# # **[END OF NOTEBOOK]**
